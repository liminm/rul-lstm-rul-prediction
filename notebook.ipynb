# %% [markdown]
# # CMAPSS RUL Notebook (Annotated)
# This notebook documents the end-to-end workflow for remaining useful life (RUL) prediction
# using the CMAPSS turbofan dataset: loading raw files, exploratory data analysis (EDA),
# feature prep, sequence construction, model training, and export.
#
# Outline:
# - Configuration and data loading
# - EDA and feature selection
# - Train/validation split and scaling
# - Sequence building and data loaders
# - Model training, evaluation, and ONNX export

# %%
from pathlib import Path
import os
import random
import torch
import numpy as np
import pandas as pd
import itertools
import random
import numpy as np
import torch
import torch.nn as nn
from model import RulLstm
import matplotlib.pyplot as plt
import copy
import math
import joblib

# %% [markdown]
# ## Configuration
# Set paths, dataset tags, and random seeds for reproducibility.

# %%
DATA_DIR = Path("data")
DATA_DIR.mkdir(parents=True, exist_ok=True)

FD_TAGS = ["FD001"]

SEED = 42
random.seed(SEED)
np.random.seed(SEED)

# %% [markdown]
# ## Data acquisition (optional)
# Download/unzip the CMAPSS data if it is not already present in `data/`.

# %%
zip_path = DATA_DIR / "CMAPSSData.zip"

os.makedirs(DATA_DIR, exist_ok=True)

if not zip_path.exists():
    os.system(f"wget https://data.nasa.gov/docs/legacy/CMAPSSData.zip -O {zip_path}")

# !unzip -o data/CMAPSSData.zip -d data/

print("Data downloaded and extracted.")
# Out:
# Archive:  data/CMAPSSData.zip
#   inflating: data/Damage Propagation Modeling.pdf
#   inflating: data/readme.txt
#   inflating: data/RUL_FD001.txt
#   inflating: data/RUL_FD002.txt
#   inflating: data/RUL_FD003.txt
#   inflating: data/RUL_FD004.txt
#   inflating: data/test_FD001.txt
#   inflating: data/test_FD002.txt
#   inflating: data/test_FD003.txt
#   inflating: data/test_FD004.txt
#   inflating: data/train_FD001.txt
#   inflating: data/train_FD002.txt
#   inflating: data/train_FD003.txt
#   inflating: data/train_FD004.txt
# Data downloaded and extracted.

# %% [markdown]
# ## Column schema
# Define column names for unit id, cycles, settings, and sensor readings.

# %%
# The dataset has 26 columns
# 1. Unit Number (Which engine is it?)
# 2. Time Cycles (How long has it been running?)
# 3-5. Operational Settings (Altitude, Speed, etc.)
# 6-26. Sensor Readings (s1 to s21)

index_names = ["unit_nr", "time_cycles"]
setting_names = ["setting_1", "setting_2", "setting_3"]
sensor_names = [f"s_{i}" for i in range(1, 22)]
col_names = index_names + setting_names + sensor_names
print("Column names:", col_names)
# Out:
# Column names: ['unit_nr', 'time_cycles', 'setting_1', 'setting_2', 'setting_3', 's_1', 's_2', 's_3', 's_4', 's_5', 's_6', 's_7', 's_8', 's_9', 's_10', 's_11', 's_12', 's_13', 's_14', 's_15', 's_16', 's_17', 's_18', 's_19', 's_20', 's_21']

# %% [markdown]
# ## Load datasets and compute RUL
# Load raw train/test files for an FD subset and compute RUL targets for training units.

# %%
data_dir = DATA_DIR
fd_tag = "FD001"
train_path = data_dir / f"train_{fd_tag}.txt"


train_df = pd.read_csv(train_path, sep=r"\s+", header=None, names=col_names)
train_df.head()
# Out:
#    unit_nr  time_cycles  setting_1  setting_2  setting_3     s_1     s_2  \
# 0        1            1    -0.0007    -0.0004      100.0  518.67  641.82
# 1        1            2     0.0019    -0.0003      100.0  518.67  642.15
# 2        1            3    -0.0043     0.0003      100.0  518.67  642.35
# 3        1            4     0.0007     0.0000      100.0  518.67  642.35
# 4        1            5    -0.0019    -0.0002      100.0  518.67  642.37
#
#        s_3      s_4    s_5  ...    s_12     s_13     s_14    s_15  s_16  s_17  \
# 0  1589.70  1400.60  14.62  ...  521.66  2388.02  8138.62  8.4195  0.03   392
# 1  1591.82  1403.14  14.62  ...  522.28  2388.07  8131.49  8.4318  0.03   392
# 2  1587.99  1404.20  14.62  ...  522.42  2388.03  8133.23  8.4178  0.03   390
# 3  1582.79  1401.87  14.62  ...  522.86  2388.08  8133.83  8.3682  0.03   392
# 4  1582.85  1406.22  14.62  ...  522.19  2388.04  8133.80  8.4294  0.03   393
#
#    s_18   s_19   s_20     s_21
# 0  2388  100.0  39.06  23.4190
# 1  2388  100.0  39.00  23.4236
# 2  2388  100.0  38.95  23.3442
# 3  2388  100.0  38.88  23.3739
# 4  2388  100.0  38.90  23.4044
#
# [5 rows x 26 columns]

# %%
test_path = data_dir / f"test_{fd_tag}.txt"
test_df = pd.read_csv(test_path, sep=r"\s+", header=None, names=col_names)
test_df.head()
# Out:
#    unit_nr  time_cycles  setting_1  setting_2  setting_3     s_1     s_2  \
# 0        1            1     0.0023     0.0003      100.0  518.67  643.02
# 1        1            2    -0.0027    -0.0003      100.0  518.67  641.71
# 2        1            3     0.0003     0.0001      100.0  518.67  642.46
# 3        1            4     0.0042     0.0000      100.0  518.67  642.44
# 4        1            5     0.0014     0.0000      100.0  518.67  642.51
#
#        s_3      s_4    s_5  ...    s_12     s_13     s_14    s_15  s_16  s_17  \
# 0  1585.29  1398.21  14.62  ...  521.72  2388.03  8125.55  8.4052  0.03   392
# 1  1588.45  1395.42  14.62  ...  522.16  2388.06  8139.62  8.3803  0.03   393
# 2  1586.94  1401.34  14.62  ...  521.97  2388.03  8130.10  8.4441  0.03   393
# 3  1584.12  1406.42  14.62  ...  521.38  2388.05  8132.90  8.3917  0.03   391
# 4  1587.19  1401.92  14.62  ...  522.15  2388.03  8129.54  8.4031  0.03   390
#
#    s_18   s_19   s_20     s_21
# 0  2388  100.0  38.86  23.3735
# 1  2388  100.0  39.02  23.3916
# 2  2388  100.0  39.08  23.4166
# 3  2388  100.0  39.00  23.3737
# 4  2388  100.0  38.99  23.4130
#
# [5 rows x 26 columns]

# %% [markdown]
# Helper functions to load each FD subset and attach RUL labels.

# %%
def load_fd(fd_tag: str, data_dir: Path) -> tuple[pd.DataFrame, pd.DataFrame, pd.DataFrame]:
    train_path = data_dir / f"train_{fd_tag}.txt"
    test_path = data_dir / f"test_{fd_tag}.txt"
    rul_path = data_dir / f"RUL_{fd_tag}.txt"

    train_df = pd.read_csv(train_path, sep=r"\s+", header=None, names=col_names)
    test_df = pd.read_csv(test_path, sep=r"\s+", header=None, names=col_names)
    rul_df = pd.read_csv(rul_path, header=None, names=["RUL_truth"])

    max_cycle = train_df.groupby("unit_nr")["time_cycles"].max().rename("max_cycle")
    train_df = train_df.merge(max_cycle, left_on="unit_nr", right_index=True)
    train_df["RUL"] = train_df["max_cycle"] - train_df["time_cycles"]

    train_df["fd"] = fd_tag
    test_df["fd"] = fd_tag
    rul_df["fd"] = fd_tag

    return train_df, test_df, rul_df

# %% [markdown]
# ## Merge FD subsets
# When using multiple FD tags, re-map unit IDs to avoid collisions and combine splits.

# %%
def make_global_unit_ids(train_df: pd.DataFrame, test_df: pd.DataFrame, fd_tag: str, next_unit: int):
    uniq_units_train = sorted(train_df["unit_nr"].unique())
    mapping_train = {u: next_unit + i for i, u in enumerate(uniq_units_train)}

    train_df = train_df.assign(
        unit_nr_orig=train_df["unit_nr"],
        unit_nr=train_df["unit_nr"].map(mapping_train),
    )

    test_df = test_df.assign(
        unit_nr_orig=test_df["unit_nr"],
        unit_nr=test_df["unit_nr"] + next_unit - 1,
    )

    next_unit = next_unit + len(uniq_units_train)
    return train_df, test_df, next_unit

# %%
next_unit = 1
train_parts = []
test_parts = []
rul_parts = []

for fd_tag in FD_TAGS:
    tr, te, rul = load_fd(fd_tag, DATA_DIR)

    tr, te, next_unit = make_global_unit_ids(tr, te, fd_tag, next_unit)

    train_parts.append(tr)
    test_parts.append(te)
    rul_parts.append(rul)

train_df = pd.concat(train_parts, ignore_index=True)
test_df = pd.concat(test_parts, ignore_index=True)
rul_labels_df = pd.concat(rul_parts, ignore_index=True)

train_df = train_df.sort_values(["unit_nr", "time_cycles"]).reset_index(drop=True)
test_df = test_df.sort_values(["unit_nr", "time_cycles"]).reset_index(drop=True)

print("Train shape:", train_df.shape)
print("Test shape:", test_df.shape)
print("RUL labels shape:", rul_labels_df.shape)
print("Unique train units:", train_df["unit_nr"].nunique())
print("Unique test units:", test_df["unit_nr"].nunique())
# Out:
# Train shape: (20631, 30)
# Test shape: (13096, 28)
# RUL labels shape: (100, 2)
# Unique train units: 100
# Unique test units: 100

# %%
train_df.head()
# Out:
#    unit_nr  time_cycles  setting_1  setting_2  setting_3     s_1     s_2  \
# 0        1            1    -0.0007    -0.0004      100.0  518.67  641.82
# 1        1            2     0.0019    -0.0003      100.0  518.67  642.15
# 2        1            3    -0.0043     0.0003      100.0  518.67  642.35
# 3        1            4     0.0007     0.0000      100.0  518.67  642.35
# 4        1            5    -0.0019    -0.0002      100.0  518.67  642.37
#
#        s_3      s_4    s_5  ...  s_16  s_17  s_18   s_19   s_20     s_21  \
# 0  1589.70  1400.60  14.62  ...  0.03   392  2388  100.0  39.06  23.4190
# 1  1591.82  1403.14  14.62  ...  0.03   392  2388  100.0  39.00  23.4236
# 2  1587.99  1404.20  14.62  ...  0.03   390  2388  100.0  38.95  23.3442
# 3  1582.79  1401.87  14.62  ...  0.03   392  2388  100.0  38.88  23.3739
# 4  1582.85  1406.22  14.62  ...  0.03   393  2388  100.0  38.90  23.4044
#
#    max_cycle  RUL     fd  unit_nr_orig
# 0        192  191  FD001             1
# 1        192  190  FD001             1
# 2        192  189  FD001             1
# 3        192  188  FD001             1
# 4        192  187  FD001             1
#
# [5 rows x 30 columns]

# %%
test_df.head()
# Out:
#    unit_nr  time_cycles  setting_1  setting_2  setting_3     s_1     s_2  \
# 0        1            1     0.0023     0.0003      100.0  518.67  643.02
# 1        1            2    -0.0027    -0.0003      100.0  518.67  641.71
# 2        1            3     0.0003     0.0001      100.0  518.67  642.46
# 3        1            4     0.0042     0.0000      100.0  518.67  642.44
# 4        1            5     0.0014     0.0000      100.0  518.67  642.51
#
#        s_3      s_4    s_5  ...     s_14    s_15  s_16  s_17  s_18   s_19  \
# 0  1585.29  1398.21  14.62  ...  8125.55  8.4052  0.03   392  2388  100.0
# 1  1588.45  1395.42  14.62  ...  8139.62  8.3803  0.03   393  2388  100.0
# 2  1586.94  1401.34  14.62  ...  8130.10  8.4441  0.03   393  2388  100.0
# 3  1584.12  1406.42  14.62  ...  8132.90  8.3917  0.03   391  2388  100.0
# 4  1587.19  1401.92  14.62  ...  8129.54  8.4031  0.03   390  2388  100.0
#
#     s_20     s_21     fd  unit_nr_orig
# 0  38.86  23.3735  FD001             1
# 1  39.02  23.3916  FD001             1
# 2  39.08  23.4166  FD001             1
# 3  39.00  23.3737  FD001             1
# 4  38.99  23.4130  FD001             1
#
# [5 rows x 28 columns]

# %%
rul_labels_df.head()
# Out:
#    RUL_truth     fd
# 0        112  FD001
# 1         98  FD001
# 2         69  FD001
# 3         82  FD001
# 4         91  FD001

# %% [markdown]
# ## Exploratory data analysis
# Assess data quality, lifecycle distributions, and sensor behavior before modeling.

# %% [markdown]
# Check for missing values, duplicates, and cycle continuity.

# %%
missing_rate = train_df.isna().mean().sort_values(ascending=False)
print("Top missing rates:")
print(missing_rate.head(10))

dup_count = train_df.duplicated().sum()
print("Duplicate rows:", dup_count)
# Out:
# Top missing rates:
# unit_nr        0.0
# time_cycles    0.0
# setting_1      0.0
# setting_2      0.0
# setting_3      0.0
# s_1            0.0
# s_2            0.0
# s_3            0.0
# s_4            0.0
# s_5            0.0
# dtype: float64
# Duplicate rows: 0

# %% [markdown]
# We have no missing values or duplicate rows.

# %%
bad_units = []
for unit_id, g in train_df.groupby("unit_nr", sort=False):
    cycles = g["time_cycles"].to_numpy()
    cycles_sorted = np.sort(cycles)

    diffs = cycles_sorted[1:] - cycles_sorted[:-1]
    ok_start = cycles_sorted[0] == 1
    ok_steps = (diffs.min() == 1) and (diffs.max() == 1)

    if not (ok_start and ok_steps):
        bad_units.append(unit_id)

print("Units with non-continuous cycles:", len(bad_units))
# Out:
# Units with non-continuous cycles: 0

# %% [markdown]
# We have no units with non-continuous cycles.

# %%
lifetimes = train_df.groupby("unit_nr")["time_cycles"].max()
print(lifetimes.describe())

print(train_df["RUL"].describe())
# Out:
# count    100.000000
# mean     206.310000
# std       46.342749
# min      128.000000
# 25%      177.000000
# 50%      199.000000
# 75%      229.250000
# max      362.000000
# Name: time_cycles, dtype: float64
# count    20631.000000
# mean       107.807862
# std         68.880990
# min          0.000000
# 25%         51.000000
# 50%        103.000000
# 75%        155.000000
# max        361.000000
# Name: RUL, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.hist(lifetimes, bins=30)
plt.title("Training set: lifetime distribution (cycles until failure)")
plt.xlabel("Lifetime (max cycles per engine)")
plt.ylabel("Number of engines")
plt.show()

# %%
plt.figure()
plt.hist(train_df["RUL"], bins=50)
plt.title("Training set: RUL distribution (all cycles)")
plt.xlabel("RUL")
plt.ylabel("Count")
plt.show()

# %%
for fd_tag, g in train_df.groupby("fd"):
    lifetimes_fd = g.groupby("unit_nr")["time_cycles"].max()

    plt.figure()
    plt.hist(lifetimes_fd, bins=30)
    plt.title(f"{fd_tag}: lifetime distribution")
    plt.xlabel("Lifetime (cycles)")
    plt.ylabel("Number of engines")
    plt.show()

# %%
feature_cols = setting_names + sensor_names

desc = train_df[feature_cols].describe().T
desc["range"] = desc["max"] - desc["min"]
desc["std"] = train_df[feature_cols].std(numeric_only=True)

desc_sorted = desc.sort_values("range")
print(desc_sorted[["min", "max", "range", "std"]].head(10))
# Out:
#                  min        max   range           std
# s_1         518.6700   518.6700  0.0000  0.000000e+00
# setting_3   100.0000   100.0000  0.0000  0.000000e+00
# s_5          14.6200    14.6200  0.0000  5.329200e-15
# s_10          1.3000     1.3000  0.0000  0.000000e+00
# s_18       2388.0000  2388.0000  0.0000  0.000000e+00
# s_19        100.0000   100.0000  0.0000  0.000000e+00
# s_16          0.0300     0.0300  0.0000  3.469531e-18
# setting_2    -0.0006     0.0006  0.0012  2.930621e-04
# s_6          21.6000    21.6100  0.0100  1.388985e-03
# setting_1    -0.0087     0.0087  0.0174  2.187313e-03

# %% [markdown]
# Sensor values span very different ranges, so we normalize later to keep training stable.

# %%
range_thresh = 1e-6
std_thresh = 1e-6

low_variance = desc[(desc["range"] <= range_thresh) | (desc["std"] <= std_thresh)].index.tolist()
print("Low-variance features:", low_variance)

features_to_drop = low_variance
# Out:
# Low-variance features: ['setting_3', 's_1', 's_5', 's_10', 's_16', 's_18', 's_19']

# %% [markdown]
# Low-variance sensors stay mostly constant and provide little signal for RUL,
# so we mark them for removal before training.

# %% [markdown]
# ### Feature relevance
# Rank features by Spearman correlation with RUL on a sample.

# %%
corrs = {}
sample_df = train_df.sample(n=min(len(train_df), 30000), random_state=SEED)

for c in feature_cols:
    corrs[c] = sample_df[c].corr(sample_df["RUL"], method="spearman")

corr_s = pd.Series(corrs).sort_values(key=lambda x: x.abs(), ascending=False)
print("Top correlations (abs Spearman):")
corr_s.head(16)
# Out:
# Top correlations (abs Spearman):
# /home/limin/Documents/programming/gemini-lstm-next-frame-prediction/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# s_11        -0.718132
# s_4         -0.701771
# s_12         0.693149
# s_7          0.678845
# s_15        -0.665905
# s_21         0.657417
# s_20         0.653336
# s_17        -0.629397
# s_2         -0.628588
# s_3         -0.605609
# s_8         -0.573864
# s_13        -0.572549
# s_9         -0.322014
# s_14        -0.201792
# s_6         -0.128070
# setting_2   -0.003776
# dtype: float64

# %% [markdown]
# We rank features by Spearman correlation to find sensors most aligned with RUL trends.

# %% [markdown]
# ### Correlation heatmap
# Visualize feature relationships (numeric columns only).

# %%
import seaborn as sns
import matplotlib.pyplot as plt

numeric = train_df.select_dtypes(include=["number"])
# Drop rows with low variance
numeric = numeric.drop(columns=features_to_drop)
# Drop original unit number as it contains no useful info
numeric = numeric.drop(columns="unit_nr_orig")
corr_matrix = numeric.corr()

plt.figure(figsize=(30, 24))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
train_df.head()
# Out:
#    unit_nr  time_cycles  setting_1  setting_2  setting_3     s_1     s_2  \
# 0        1            1    -0.0007    -0.0004      100.0  518.67  641.82
# 1        1            2     0.0019    -0.0003      100.0  518.67  642.15
# 2        1            3    -0.0043     0.0003      100.0  518.67  642.35
# 3        1            4     0.0007     0.0000      100.0  518.67  642.35
# 4        1            5    -0.0019    -0.0002      100.0  518.67  642.37
#
#        s_3      s_4    s_5  ...  s_16  s_17  s_18   s_19   s_20     s_21  \
# 0  1589.70  1400.60  14.62  ...  0.03   392  2388  100.0  39.06  23.4190
# 1  1591.82  1403.14  14.62  ...  0.03   392  2388  100.0  39.00  23.4236
# 2  1587.99  1404.20  14.62  ...  0.03   390  2388  100.0  38.95  23.3442
# 3  1582.79  1401.87  14.62  ...  0.03   392  2388  100.0  38.88  23.3739
# 4  1582.85  1406.22  14.62  ...  0.03   393  2388  100.0  38.90  23.4044
#
#    max_cycle  RUL     fd  unit_nr_orig
# 0        192  191  FD001             1
# 1        192  190  FD001             1
# 2        192  189  FD001             1
# 3        192  188  FD001             1
# 4        192  187  FD001             1
#
# [5 rows x 30 columns]

# %% [markdown]
# We can see that s_9 and s_14 are highly correlated. We drop s_14 (lower RUL correlation)
# to reduce redundancy and noise.

# %%
# we drop the low-variance features identified earlier, the original unit number, and the original fd
features_to_drop.append("unit_nr_orig")
features_to_drop.append("fd")
features_to_drop.append("s_14")  # Low variance
features_to_drop = list(set(features_to_drop))  # Remove duplicates
print(f"features_to_drop = {features_to_drop}")
# Out:
# features_to_drop = ['s_10', 's_19', 's_18', 'fd', 'setting_3', 's_1', 's_14', 'unit_nr_orig', 's_5', 's_16']

# %% [markdown]
# Plot sensor trajectories over cycles to visualize degradation patterns.

# %%
# Plot time series of top correlated sensors for some units
top_n = 12
top_sensors = corr_s.head(top_n).index.tolist()

# We randomly select 3 units to plot
units_to_plot = np.random.default_rng(SEED).choice(train_df["unit_nr"].unique(), size=3, replace=False).tolist()


for unit_id in units_to_plot:
    g = train_df[train_df["unit_nr"] == unit_id].sort_values("time_cycles")

    X = g[top_sensors].to_numpy()
    #Xz = StandardScaler().fit_transform(X)

    cols = 3
    rows = (top_n + cols - 1) // cols
    fig, axes = plt.subplots(rows, cols, figsize=(12, 3 * rows), sharex=True)
    axes = axes.ravel()

    for i, s in enumerate(top_sensors):
        axes[i].plot(g["time_cycles"], X[:, i])
        axes[i].set_title(f"{s} (ρ={corr_s[s]:.2f})", fontsize=9)
        axes[i].grid(True)

    for ax in axes[top_n:]:
        ax.axis("off")

    fig.suptitle(f"Unit {unit_id}: top {top_n} sensors (z-score)")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## EDA Conclusion
# - Data quality is strong: no material missing/duplicate rows and cycles are continuous.
# - RUL spans a wide, right-skewed range, so targets are scaled (or kept raw by choice).
# - Sensor ranges vary widely, which supports MinMax scaling before training.
# - A small set of sensors shows strong RUL correlation (e.g., s_11, s_4, s_8, s_17, s_13).
# - Some settings/sensors are constant or near-constant and can be dropped.
# - Highly correlated pairs (e.g., s_9 vs s_14) can be pruned to reduce redundancy.
# - The final feature set is compact but informative for LSTM sequence modeling.

# %% [markdown]
# ## Feature Selection
# Drop low-variance sensors and redundant features identified in EDA.

# %%
# check what features to drop
print(features_to_drop)
# Out:
# ['s_10', 's_19', 's_18', 'fd', 'setting_3', 's_1', 's_14', 'unit_nr_orig', 's_5', 's_16']

# %%
# we drop the low-variance features identified earlier and the original unit number
train_df = train_df.drop(columns=features_to_drop, errors="ignore")
test_df = test_df.drop(columns=features_to_drop, errors="ignore")

# %%
train_df.head()
# Out:
#    unit_nr  time_cycles  setting_1  setting_2     s_2      s_3      s_4  \
# 0        1            1    -0.0007    -0.0004  641.82  1589.70  1400.60
# 1        1            2     0.0019    -0.0003  642.15  1591.82  1403.14
# 2        1            3    -0.0043     0.0003  642.35  1587.99  1404.20
# 3        1            4     0.0007     0.0000  642.35  1582.79  1401.87
# 4        1            5    -0.0019    -0.0002  642.37  1582.85  1406.22
#
#      s_6     s_7      s_8      s_9   s_11    s_12     s_13    s_15  s_17  \
# 0  21.61  554.36  2388.06  9046.19  47.47  521.66  2388.02  8.4195   392
# 1  21.61  553.75  2388.04  9044.07  47.49  522.28  2388.07  8.4318   392
# 2  21.61  554.26  2388.08  9052.94  47.27  522.42  2388.03  8.4178   390
# 3  21.61  554.45  2388.11  9049.48  47.13  522.86  2388.08  8.3682   392
# 4  21.61  554.00  2388.06  9055.15  47.28  522.19  2388.04  8.4294   393
#
#     s_20     s_21  max_cycle  RUL
# 0  39.06  23.4190        192  191
# 1  39.00  23.4236        192  190
# 2  38.95  23.3442        192  189
# 3  38.88  23.3739        192  188
# 4  38.90  23.4044        192  187

# %%
test_df.head()
# Out:
#    unit_nr  time_cycles  setting_1  setting_2     s_2      s_3      s_4  \
# 0        1            1     0.0023     0.0003  643.02  1585.29  1398.21
# 1        1            2    -0.0027    -0.0003  641.71  1588.45  1395.42
# 2        1            3     0.0003     0.0001  642.46  1586.94  1401.34
# 3        1            4     0.0042     0.0000  642.44  1584.12  1406.42
# 4        1            5     0.0014     0.0000  642.51  1587.19  1401.92
#
#      s_6     s_7      s_8      s_9   s_11    s_12     s_13    s_15  s_17  \
# 0  21.61  553.90  2388.04  9050.17  47.20  521.72  2388.03  8.4052   392
# 1  21.61  554.85  2388.01  9054.42  47.50  522.16  2388.06  8.3803   393
# 2  21.61  554.11  2388.05  9056.96  47.50  521.97  2388.03  8.4441   393
# 3  21.61  554.07  2388.03  9045.29  47.28  521.38  2388.05  8.3917   391
# 4  21.61  554.16  2388.01  9044.55  47.31  522.15  2388.03  8.4031   390
#
#     s_20     s_21
# 0  38.86  23.3735
# 1  39.02  23.3916
# 2  39.08  23.4166
# 3  39.00  23.3737
# 4  38.99  23.4130

# %% [markdown]
# ## Train/validation split
# Split by engine unit to avoid leakage across cycles.

# %%
def split_by_unit(df: pd.DataFrame, val_frac: float, seed: int):
    units = df["unit_nr"].unique()
    rng = np.random.default_rng(seed)
    rng.shuffle(units)

    n_val = int(np.ceil(len(units) * val_frac))
    val_units = set(units[:n_val])
    train_units = set(units[n_val:])

    train_split = df[df["unit_nr"].isin(train_units)].copy()
    val_split = df[df["unit_nr"].isin(val_units)].copy()

    return train_split, val_split, sorted(train_units), sorted(val_units)

train_split_df, val_split_df, train_units, val_units = split_by_unit(train_df, val_frac=0.2, seed=SEED)

print("Train split shape:", train_split_df.shape, "units:", len(train_units))
print("Val split shape:", val_split_df.shape, "units:", len(val_units))
# Out:
# Train split shape: (16779, 20) units: 80
# Val split shape: (3852, 20) units: 20

# %%
train_split_df.head()
# Out:
#    unit_nr  time_cycles  setting_1  setting_2     s_2      s_3      s_4  \
# 0        1            1    -0.0007    -0.0004  641.82  1589.70  1400.60
# 1        1            2     0.0019    -0.0003  642.15  1591.82  1403.14
# 2        1            3    -0.0043     0.0003  642.35  1587.99  1404.20
# 3        1            4     0.0007     0.0000  642.35  1582.79  1401.87
# 4        1            5    -0.0019    -0.0002  642.37  1582.85  1406.22
#
#      s_6     s_7      s_8      s_9   s_11    s_12     s_13    s_15  s_17  \
# 0  21.61  554.36  2388.06  9046.19  47.47  521.66  2388.02  8.4195   392
# 1  21.61  553.75  2388.04  9044.07  47.49  522.28  2388.07  8.4318   392
# 2  21.61  554.26  2388.08  9052.94  47.27  522.42  2388.03  8.4178   390
# 3  21.61  554.45  2388.11  9049.48  47.13  522.86  2388.08  8.3682   392
# 4  21.61  554.00  2388.06  9055.15  47.28  522.19  2388.04  8.4294   393
#
#     s_20     s_21  max_cycle  RUL
# 0  39.06  23.4190        192  191
# 1  39.00  23.4236        192  190
# 2  38.95  23.3442        192  189
# 3  38.88  23.3739        192  188
# 4  38.90  23.4044        192  187

# %%
val_split_df.head()
# Out:
#      unit_nr  time_cycles  setting_1  setting_2     s_2      s_3      s_4  \
# 479        3            1     0.0008     0.0005  642.04  1584.20  1398.13
# 480        3            2    -0.0010     0.0000  642.66  1587.04  1398.62
# 481        3            3     0.0013    -0.0002  642.07  1580.75  1401.10
# 482        3            4     0.0008    -0.0002  642.50  1580.12  1395.76
# 483        3            5     0.0020     0.0004  641.97  1581.48  1394.05
#
#        s_6     s_7      s_8      s_9   s_11    s_12     s_13    s_15  s_17  \
# 479  21.61  553.96  2388.06  9056.95  47.14  522.24  2388.00  8.4207   391
# 480  21.61  554.76  2388.05  9059.67  47.35  522.03  2388.01  8.3949   390
# 481  21.61  554.51  2388.03  9050.43  46.94  522.16  2388.01  8.3820   393
# 482  21.61  554.48  2388.07  9060.43  47.44  522.31  2388.07  8.3940   391
# 483  21.61  554.14  2388.01  9054.36  47.16  522.00  2388.03  8.4233   391
#
#       s_20     s_21  max_cycle  RUL
# 479  38.96  23.3205        179  178
# 480  39.07  23.4369        179  177
# 481  39.03  23.3162        179  176
# 482  38.94  23.4901        179  175
# 483  38.90  23.4190        179  174

# %% [markdown]
# ## Scaling
# Fit MinMax scaling on train split and apply to validation/test.
#
# Sensor ranges differ by orders of magnitude; scaling prevents large‑scale sensors from dominating the loss and helps the LSTM train stably.

# %%
from sklearn.preprocessing import MinMaxScaler


not_scaled_cols = ['unit_nr', 'RUL', 'max_cycle', 'time_cycles']

col_set = train_split_df.columns
columns_to_scale = [col for col in col_set if col not in not_scaled_cols]

print("Columns to scale:", columns_to_scale)

scaler = MinMaxScaler(feature_range=(0, 1))
scaled_train_split = scaler.fit_transform(train_split_df[columns_to_scale])
scaled_train_split_df = pd.DataFrame(scaled_train_split, columns=columns_to_scale, index=train_split_df.index)
scaled_val_split = scaler.transform(val_split_df[columns_to_scale])
scaled_val_split_df = pd.DataFrame(scaled_val_split, columns=columns_to_scale, index=val_split_df.index)
scaled_test = scaler.transform(test_df[columns_to_scale])
scaled_test_df = pd.DataFrame(scaled_test, columns=columns_to_scale, index=test_df.index)


scaled_train_split_df.insert(0, 'unit_nr', train_split_df['unit_nr'])
scaled_train_split_df.insert(1, 'time_cycles', train_split_df['time_cycles'])
scaled_train_split_df.insert(len(scaled_train_split_df.columns), 'RUL', train_split_df['RUL'])
scaled_train_split_df.insert(len(scaled_train_split_df.columns), 'max_cycle', train_split_df['max_cycle'])

scaled_val_split_df.insert(0, 'unit_nr', val_split_df['unit_nr'])
scaled_val_split_df.insert(1, 'time_cycles', val_split_df['time_cycles'])
scaled_val_split_df.insert(len(scaled_val_split_df.columns), 'RUL', val_split_df['RUL'])
scaled_val_split_df.insert(len(scaled_val_split_df.columns), 'max_cycle', val_split_df['max_cycle'])

scaled_test_df.insert(0, 'unit_nr', test_df['unit_nr'])
scaled_test_df.insert(1, 'time_cycles', test_df['time_cycles'])
# Out:
# Columns to scale: ['setting_1', 'setting_2', 's_2', 's_3', 's_4', 's_6', 's_7', 's_8', 's_9', 's_11', 's_12', 's_13', 's_15', 's_17', 's_20', 's_21']

# %%
scaled_train_split_df.head()
# Out:
#    unit_nr  time_cycles  setting_1  setting_2       s_2       s_3       s_4  \
# 0        1            1   0.459770   0.166667  0.183735  0.406802  0.309757
# 1        1            2   0.609195   0.250000  0.283133  0.453019  0.352633
# 2        1            3   0.252874   0.750000  0.343373  0.369523  0.370527
# 3        1            4   0.540230   0.500000  0.343373  0.256159  0.331195
# 4        1            5   0.390805   0.333333  0.349398  0.257467  0.404625
#
#    s_6       s_7       s_8       s_9      s_11      s_12      s_13      s_15  \
# 0  1.0  0.726248  0.258065  0.112186  0.369048  0.633262  0.205882  0.363986
# 1  1.0  0.628019  0.225806  0.102463  0.380952  0.765458  0.279412  0.411312
# 2  1.0  0.710145  0.290323  0.143145  0.250000  0.795309  0.220588  0.357445
# 3  1.0  0.740741  0.338710  0.127276  0.166667  0.889126  0.294118  0.166603
# 4  1.0  0.668277  0.258065  0.153282  0.255952  0.746269  0.235294  0.402078
#
#        s_17      s_20      s_21  RUL  max_cycle
# 0  0.333333  0.701613  0.730411  191        192
# 1  0.333333  0.653226  0.736813  190        192
# 2  0.166667  0.612903  0.626305  189        192
# 3  0.333333  0.556452  0.667641  188        192
# 4  0.416667  0.572581  0.710090  187        192

# %%
scaled_val_split_df.head()
# Out:
#      unit_nr  time_cycles  setting_1  setting_2       s_2       s_3       s_4  \
# 479        3            1   0.545977   0.916667  0.250000  0.286898  0.268062
# 480        3            2   0.442529   0.500000  0.436747  0.348812  0.276334
# 481        3            3   0.574713   0.333333  0.259036  0.211685  0.318197
# 482        3            4   0.545977   0.333333  0.388554  0.197951  0.228055
# 483        3            5   0.614943   0.833333  0.228916  0.227600  0.199190
#
#      s_6       s_7       s_8       s_9      s_11      s_12      s_13  \
# 479  1.0  0.661836  0.258065  0.161537  0.172619  0.756930  0.176471
# 480  1.0  0.790660  0.241935  0.174013  0.297619  0.712154  0.191176
# 481  1.0  0.750403  0.209677  0.131633  0.053571  0.739872  0.191176
# 482  1.0  0.745572  0.274194  0.177499  0.351190  0.771855  0.279412
# 483  1.0  0.690821  0.177419  0.149658  0.184524  0.705757  0.220588
#
#          s_15      s_17      s_20      s_21  RUL  max_cycle
# 479  0.368603  0.250000  0.620968  0.593319  178        179
# 480  0.269334  0.166667  0.709677  0.755324  177        179
# 481  0.219700  0.416667  0.677419  0.587335  176        179
# 482  0.265871  0.250000  0.604839  0.829367  175        179
# 483  0.378607  0.250000  0.572581  0.730411  174        179

# %%
scaled_test_df.head()
# Out:
#    unit_nr  time_cycles  setting_1  setting_2       s_2       s_3       s_4  \
# 0        1            1   0.632184   0.750000  0.545181  0.310661  0.269413
# 1        1            2   0.344828   0.250000  0.150602  0.379551  0.222316
# 2        1            3   0.517241   0.583333  0.376506  0.346632  0.322248
# 3        1            4   0.741379   0.500000  0.370482  0.285154  0.408001
# 4        1            5   0.580460   0.500000  0.391566  0.352082  0.332039
#
#    s_6       s_7       s_8       s_9      s_11      s_12      s_13      s_15  \
# 0  1.0  0.652174  0.225806  0.130441  0.208333  0.646055  0.220588  0.308965
# 1  1.0  0.805153  0.177419  0.149933  0.386905  0.739872  0.264706  0.213159
# 2  1.0  0.685990  0.241935  0.161583  0.386905  0.699360  0.220588  0.458638
# 3  1.0  0.679549  0.209677  0.108059  0.255952  0.573561  0.250000  0.257022
# 4  1.0  0.694042  0.177419  0.104664  0.273810  0.737740  0.220588  0.300885
#
#        s_17      s_20      s_21
# 0  0.333333  0.540323  0.667084
# 1  0.416667  0.669355  0.692276
# 2  0.416667  0.717742  0.727070
# 3  0.250000  0.653226  0.667363
# 4  0.166667  0.645161  0.722060

# %% [markdown]
# ## Save the fitted scaler

# %%
if not os.path.exists('models'):
    os.makedirs('models')

joblib.dump(scaler, 'models/scaler.pkl')
print("Scaler saved to models/scaler.pkl")
# Out:
# Scaler saved to models/scaler.pkl

# %% [markdown]
# ### Check scaled ranges
# Confirm that scaled features are within [0, 1] after MinMax scaling.

# %%
import matplotlib.pyplot as plt
import numpy as np 

columns_to_scale = setting_names + sensor_names

not_scaled_cols = ['unit_nr', 'RUL', 'max_cycle', 'time_cycles']

col_set = train_split_df.columns
columns_to_scale = [col for col in col_set if col not in not_scaled_cols]

print("Columns to scale:", columns_to_scale)

ranges = (train_split_df[columns_to_scale].max() - train_split_df[columns_to_scale].min()).sort_values(ascending=False)

plt.figure()
plt.bar(np.arange(len(ranges)), ranges.to_numpy())
plt.title("Per-feature range before scaling (train split)")
plt.xlabel("feature rank")
plt.ylabel("range")
plt.show()

scaled_ranges = (scaled_train_split_df[columns_to_scale].max() - scaled_train_split_df[columns_to_scale].min()).sort_values(ascending=False)

plt.figure()
plt.bar(np.arange(len(scaled_ranges)), scaled_ranges.to_numpy())
plt.title("Per-feature range after MinMax scaling (train split)")
plt.xlabel("feature rank")
plt.ylabel("range")
plt.show()
# Out:
# Columns to scale: ['setting_1', 'setting_2', 's_2', 's_3', 's_4', 's_6', 's_7', 's_8', 's_9', 's_11', 's_12', 's_13', 's_15', 's_17', 's_20', 's_21']

# %% [markdown]
# ## Convert data to tensors for training
# Build per-unit sequences and aligned RUL targets for variable-length modeling.

# %%
sequences_by_unit = {}
rul_by_unit = {}

non_train_feature_cols = ['unit_nr', 'time_cycles', 'RUL', 'max_cycle']
feature_cols = [c for c in scaled_train_split_df.columns if c not in non_train_feature_cols]

print("Feature columns:", feature_cols,"count features:" ,len(feature_cols))

def build_unit_dicts(df, feature_cols=feature_cols):
    sequences_by_unit = {}
    rul_by_unit = {}

    df = df.sort_values(["unit_nr", "time_cycles"])

    for unit_id, g in df.groupby("unit_nr", sort=False):
        x = torch.tensor(g[feature_cols].to_numpy(), dtype=torch.float32)
        y = torch.tensor(g["RUL"].to_numpy(), dtype=torch.float32)

        sequences_by_unit[int(unit_id)] = x
        rul_by_unit[int(unit_id)] = y

    return sequences_by_unit, rul_by_unit

train_sequences_by_unit, train_rul_by_unit = build_unit_dicts(scaled_train_split_df)
val_sequences_by_unit, val_rul_by_unit = build_unit_dicts(scaled_val_split_df)

train_unit_nr = list(train_sequences_by_unit.keys())[0]
val_unit_nr = list(val_sequences_by_unit.keys())[0]
print("train_sequences_by_unit", len(train_sequences_by_unit), "unit shape", train_sequences_by_unit[train_unit_nr].shape)
print("train_rul_by_unit", len(train_rul_by_unit), "unit shape", train_rul_by_unit[train_unit_nr].shape)
print("val_sequences_by_unit", len(val_sequences_by_unit), "unit shape", val_sequences_by_unit[val_unit_nr].shape)
print("val_rul_by_unit", len(val_rul_by_unit), "unit shape", val_rul_by_unit[val_unit_nr].shape)
# Out:
# Feature columns: ['setting_1', 'setting_2', 's_2', 's_3', 's_4', 's_6', 's_7', 's_8', 's_9', 's_11', 's_12', 's_13', 's_15', 's_17', 's_20', 's_21'] count features: 16
# train_sequences_by_unit 80 unit shape torch.Size([192, 16])
# train_rul_by_unit 80 unit shape torch.Size([192])
# val_sequences_by_unit 20 unit shape torch.Size([179, 16])
# val_rul_by_unit 20 unit shape torch.Size([179])

# %%
non_train_feature_cols = ['unit_nr', 'time_cycles', 'RUL', 'max_cycle']
feature_cols = [c for c in scaled_train_split_df.columns if c not in non_train_feature_cols]

print("Feature columns:", feature_cols,"count features:" ,len(feature_cols))

def build_test_sequences(df):
    sequences = {}
    df = df.sort_values(["unit_nr", "time_cycles"])

    for unit_id, g in df.groupby("unit_nr", sort=False):
        x = torch.tensor(g[feature_cols].to_numpy(), dtype=torch.float32)
        sequences[int(unit_id)] = x

    return sequences

test_sequences_by_unit = build_test_sequences(scaled_test_df)

rul_truth = rul_labels_df["RUL_truth"].to_numpy().astype(float)
test_unit_ids = sorted(test_sequences_by_unit.keys())

test_targets_by_unit = {unit_id: float(rul_truth[i]) for i, unit_id in enumerate(test_unit_ids)}
print("test_sequences_by_unit", len(test_sequences_by_unit))
print("test_sequences_by_unit[0]", test_sequences_by_unit[1].shape)
# Out:
# Feature columns: ['setting_1', 'setting_2', 's_2', 's_3', 's_4', 's_6', 's_7', 's_8', 's_9', 's_11', 's_12', 's_13', 's_15', 's_17', 's_20', 's_21'] count features: 16
# test_sequences_by_unit 100
# test_sequences_by_unit[0] torch.Size([31, 16])

# %%
print("Feature columns:", feature_cols,"count features:" ,len(feature_cols))
print("len(scaled_test_df.columns):", len(scaled_test_df.columns))
scaled_test_df.head()
# Out:
# Feature columns: ['setting_1', 'setting_2', 's_2', 's_3', 's_4', 's_6', 's_7', 's_8', 's_9', 's_11', 's_12', 's_13', 's_15', 's_17', 's_20', 's_21'] count features: 16
# len(scaled_test_df.columns): 18
#    unit_nr  time_cycles  setting_1  setting_2       s_2       s_3       s_4  \
# 0        1            1   0.632184   0.750000  0.545181  0.310661  0.269413
# 1        1            2   0.344828   0.250000  0.150602  0.379551  0.222316
# 2        1            3   0.517241   0.583333  0.376506  0.346632  0.322248
# 3        1            4   0.741379   0.500000  0.370482  0.285154  0.408001
# 4        1            5   0.580460   0.500000  0.391566  0.352082  0.332039
#
#    s_6       s_7       s_8       s_9      s_11      s_12      s_13      s_15  \
# 0  1.0  0.652174  0.225806  0.130441  0.208333  0.646055  0.220588  0.308965
# 1  1.0  0.805153  0.177419  0.149933  0.386905  0.739872  0.264706  0.213159
# 2  1.0  0.685990  0.241935  0.161583  0.386905  0.699360  0.220588  0.458638
# 3  1.0  0.679549  0.209677  0.108059  0.255952  0.573561  0.250000  0.257022
# 4  1.0  0.694042  0.177419  0.104664  0.273810  0.737740  0.220588  0.300885
#
#        s_17      s_20      s_21
# 0  0.333333  0.540323  0.667084
# 1  0.416667  0.669355  0.692276
# 2  0.416667  0.717742  0.727070
# 3  0.250000  0.653226  0.667363
# 4  0.166667  0.645161  0.722060

# %% [markdown]
# ## Random-crop training loader
# Sample variable-length windows from each unit to improve robustness.

# %%
from typing import List, Tuple
import torch
from torch.nn.utils.rnn import pad_sequence

# Pad sequence windows as they can have variable lengths
def collate_pad(batch: List[Tuple[torch.Tensor, float, int]]):
    seqs, targets, lengths = zip(*batch)

    lengths_t = torch.tensor(lengths, dtype=torch.long)
    padded = pad_sequence(seqs, batch_first=True)
    targets_t = torch.tensor(targets, dtype=torch.float32)

    return padded.float(), lengths_t, targets_t

# %%
from torch.utils.data import DataLoader
from dataset import CmapssRandomCropDataset, CmapssFullDataset

def make_loader(sequences_by_unit, targets_by_unit, samples_per_epoch, batch_size, l_min, l_max, num_workers=0, train=True):
    drop_last = True
    
    if train:
        ds = CmapssRandomCropDataset(
            sequences_by_unit=sequences_by_unit,
            targets_by_unit=targets_by_unit,
            samples_per_epoch=samples_per_epoch,
            l_min=l_min,
            l_max=l_max,
        )
    else:
        drop_last = False

        ds = CmapssFullDataset(
        sequences_by_unit=sequences_by_unit,
        targets_by_unit=targets_by_unit,
    )

    loader = DataLoader(
        ds,
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers,
        collate_fn=collate_pad,
        drop_last=drop_last,
        pin_memory=True,
    )

    return loader

# %% [markdown]
# ## Evaluation dataset
# Use full sequences (no random cropping) for consistent evaluation metrics.

# %%
from torch.utils.data import DataLoader
from dataset import CmapssFullDataset

test_ds = CmapssFullDataset(
    sequences_by_unit=test_sequences_by_unit,
    targets_by_unit=test_targets_by_unit,
)

test_loader = DataLoader(
    test_ds,
    batch_size=32,
    shuffle=False,
    num_workers=0,
    collate_fn=collate_pad,
    drop_last=False,
    pin_memory=True,
)

# %%
test_loader = make_loader(test_sequences_by_unit, test_targets_by_unit, samples_per_epoch=0, batch_size=32, l_min=30, l_max=200, train=False)

# %% [markdown]
# ## Training loop
# Run train/validation epochs and track loss over time.

# %%
def run_epoch(model, loader, loss_fn, device, train: bool, optimizer=None):
    if train:
        model.train()
    else:
        model.eval()

    total_loss = 0.0
    total_samples = 0

    if train:
        context = torch.enable_grad()
    else:
        context = torch.no_grad()

    with context:
        for padded, lengths, targets in loader:
            padded = padded.to(device)
            lengths = lengths.to(device)
            targets = targets.to(device)

            preds = model(padded, lengths)
            loss = loss_fn(preds, targets)

            bs = targets.size(0)
            total_loss += loss.item() * bs
            total_samples += bs

            if train:
                optimizer.zero_grad()
                loss.backward()
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
                optimizer.step()

    return total_loss / max(total_samples, 1)

# %%
def train_full(epochs, model, train_loader, val_loader, optimizer, device):
    if not os.path.exists('models'):
        os.makedirs('models')
    
    loss_fn = nn.SmoothL1Loss(reduction="mean")

    best_val = float("inf")
    best_state = None

    for epoch in range(epochs):
        train_loss = run_epoch(
            model=model,
            loader=train_loader,
            loss_fn=loss_fn,
            device=device,
            train=True,
            optimizer=optimizer,
        )

        val_loss = run_epoch(
            model=model,
            loader=val_loader,
            loss_fn=loss_fn,
            device=device,
            train=False,
            optimizer=None,
        )

        print(
            f"Epoch {epoch+1}/{epochs} "
            f"train_loss: {train_loss:.4f} | val_loss: {val_loss:.4f}"
        )

        if val_loss < best_val:
            best_val = val_loss
            best_state = copy.deepcopy(model.state_dict())

    if best_state is not None:
        model.load_state_dict(best_state)
        torch.save(best_state, 'models/lstm_model.pth')
        print("Model weights saved to models/lstm_model.pth")

    return best_val

# %% [markdown]
# ## Model definition
# Configure the LSTM model for sequence regression.
#
# ### Hyperparameter tuning
# Run trials to compare architectures and training settings.

# %%
EPOCHS = 10

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

def set_seed(seed: int):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

def run_trial(params, seed=0):
    set_seed(seed)

    train_loader = make_loader(
        train_sequences_by_unit,
        train_rul_by_unit,
        samples_per_epoch=params["samples_per_epoch"],
        batch_size=params["batch_size"],
        l_min=params["l_min"],
        l_max=params["l_max"],
    )
    val_loader = make_loader(
        val_sequences_by_unit,
        val_rul_by_unit,
        samples_per_epoch=params.get("val_samples_per_epoch", 14000),
        batch_size=params["batch_size"],
        l_min=params["l_min"],
        l_max=params.get("val_l_max", params["l_max"]),
    )

    model = RulLstm(
        n_features=len(feature_cols),
        hidden_size=params["hidden_size"],
        num_layers=params["num_layers"],
        dropout=params["dropout"],
    ).to(device)

    optimizer = torch.optim.AdamW(
        model.parameters(),
        lr=params["lr"],
        weight_decay=params["weight_decay"],
    )

    return train_full(EPOCHS, model, train_loader, val_loader, optimizer, device)

search_space = {
    "hidden_size": [64],
    "num_layers": [1, 2],
    "dropout": [0.0,0.3],
    "lr": [1e-3, 2e-3, 5e-4],
    "weight_decay": [0.0, 1e-4],
    "batch_size": [16, 32],
    "samples_per_epoch": [60000],
    "l_min": [30],
    "l_max": [200],
}


keys = list(search_space.keys())
candidates = [dict(zip(keys, vals)) for vals in itertools.product(*(search_space[k] for k in keys))]

best = (float("inf"), None)
results = []

from pathlib import Path

results_path = Path("tuning_results.txt")
with results_path.open("w", encoding="utf-8") as f:
    f.write("trial\tval_loss\tparams\n")

    for i, params in enumerate(candidates):
        print(f"Trial {i+1}/{len(candidates)} with params: {params}")
        val_loss = run_trial(params, seed=123 + i)
        results.append({**params, "val_loss": val_loss})
        if val_loss < best[0]:
            best = (val_loss, params)

        f.write(f"{i+1}\t{val_loss:.6f}\t{params}\n")
        f.flush()

print("best:", best)
# Out:
# Using device: cuda
# Trial 1/48 with params: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0, 'batch_size': 16, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 14.0123 | val_loss: 8.2307
# Epoch 2/10 train_loss: 9.3293 | val_loss: 7.2896
# Epoch 3/10 train_loss: 9.0999 | val_loss: 7.9163
# Epoch 4/10 train_loss: 8.7708 | val_loss: 7.4302
# Epoch 5/10 train_loss: 8.4601 | val_loss: 8.4274
# Epoch 6/10 train_loss: 8.3191 | val_loss: 6.5875
# Epoch 7/10 train_loss: 7.9557 | val_loss: 6.8729
# Epoch 8/10 train_loss: 7.6274 | val_loss: 6.2065
# Epoch 9/10 train_loss: 7.2744 | val_loss: 6.3793
# Epoch 10/10 train_loss: 7.1293 | val_loss: 6.3332
# Model weights saved to models/lstm_model.pth
# Trial 2/48 with params: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0, 'batch_size': 32, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 17.4795 | val_loss: 7.8473
# Epoch 2/10 train_loss: 9.5961 | val_loss: 7.5932
# Epoch 3/10 train_loss: 9.0900 | val_loss: 7.3137
# Epoch 4/10 train_loss: 8.9081 | val_loss: 6.8751
# Epoch 5/10 train_loss: 8.6665 | val_loss: 7.2579
# Epoch 6/10 train_loss: 8.3771 | val_loss: 7.3852
# Epoch 7/10 train_loss: 8.2437 | val_loss: 7.2832
# Epoch 8/10 train_loss: 8.0742 | val_loss: 6.9793
# Epoch 9/10 train_loss: 7.8899 | val_loss: 7.5113
# Epoch 10/10 train_loss: 7.4862 | val_loss: 6.6848
# Model weights saved to models/lstm_model.pth
# Trial 3/48 with params: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 16, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 14.1974 | val_loss: 7.1839
# Epoch 2/10 train_loss: 9.3590 | val_loss: 6.9736
# Epoch 3/10 train_loss: 8.9608 | val_loss: 6.6995
# Epoch 4/10 train_loss: 8.8515 | val_loss: 7.1884
# Epoch 5/10 train_loss: 8.5167 | val_loss: 6.5114
# Epoch 6/10 train_loss: 8.0988 | val_loss: 7.5909
# Epoch 7/10 train_loss: 7.7058 | val_loss: 7.2369
# Epoch 8/10 train_loss: 7.3359 | val_loss: 6.5352
# Epoch 9/10 train_loss: 7.1174 | val_loss: 6.6110
# Epoch 10/10 train_loss: 6.8290 | val_loss: 6.8430
# Model weights saved to models/lstm_model.pth
# Trial 4/48 with params: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 32, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 16.8320 | val_loss: 7.5499
# Epoch 2/10 train_loss: 9.6852 | val_loss: 7.1934
# Epoch 3/10 train_loss: 9.1977 | val_loss: 7.2846
# Epoch 4/10 train_loss: 8.8602 | val_loss: 7.3508
# Epoch 5/10 train_loss: 8.5943 | val_loss: 6.9399
# Epoch 6/10 train_loss: 8.4824 | val_loss: 7.3972
# Epoch 7/10 train_loss: 8.2980 | val_loss: 6.8605
# Epoch 8/10 train_loss: 8.1499 | val_loss: 7.1119
# Epoch 9/10 train_loss: 7.9691 | val_loss: 6.9375
# Epoch 10/10 train_loss: 7.7236 | val_loss: 6.9409
# Model weights saved to models/lstm_model.pth
# Trial 5/48 with params: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.002, 'weight_decay': 0.0, 'batch_size': 16, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 12.8960 | val_loss: 8.2212
# Epoch 2/10 train_loss: 9.2703 | val_loss: 6.5063
# Epoch 3/10 train_loss: 8.8818 | val_loss: 6.5596
# Epoch 4/10 train_loss: 8.5668 | val_loss: 7.4947
# Epoch 5/10 train_loss: 7.8422 | val_loss: 6.8182
# Epoch 6/10 train_loss: 7.3827 | val_loss: 6.8700
# Epoch 7/10 train_loss: 6.9583 | val_loss: 6.7454
# Epoch 8/10 train_loss: 6.6780 | val_loss: 6.9338
# Epoch 9/10 train_loss: 6.4937 | val_loss: 6.7925
# Epoch 10/10 train_loss: 6.2226 | val_loss: 6.6445
# Model weights saved to models/lstm_model.pth
# Trial 6/48 with params: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.002, 'weight_decay': 0.0, 'batch_size': 32, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 15.0353 | val_loss: 6.8939
# Epoch 2/10 train_loss: 9.3816 | val_loss: 6.9933
# Epoch 3/10 train_loss: 9.1359 | val_loss: 6.7600
# Epoch 4/10 train_loss: 8.8451 | val_loss: 7.0110
# Epoch 5/10 train_loss: 8.7455 | val_loss: 7.0404
# Epoch 6/10 train_loss: 8.4335 | val_loss: 6.5696
# Epoch 7/10 train_loss: 8.2257 | val_loss: 6.9115
# Epoch 8/10 train_loss: 8.1020 | val_loss: 7.2957
# Epoch 9/10 train_loss: 7.8389 | val_loss: 7.8096
# Epoch 10/10 train_loss: 7.7515 | val_loss: 7.0897
# Model weights saved to models/lstm_model.pth
# Trial 7/48 with params: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.002, 'weight_decay': 0.0001, 'batch_size': 16, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 13.0518 | val_loss: 7.9178
# Epoch 2/10 train_loss: 9.2602 | val_loss: 6.8861
# Epoch 3/10 train_loss: 8.9730 | val_loss: 8.3521
# Epoch 4/10 train_loss: 8.7397 | val_loss: 7.0284
# Epoch 5/10 train_loss: 8.3259 | val_loss: 7.5533
# Epoch 6/10 train_loss: 7.7093 | val_loss: 7.1194
# Epoch 7/10 train_loss: 7.4051 | val_loss: 6.4615
# Epoch 8/10 train_loss: 6.9948 | val_loss: 6.1156
# Epoch 9/10 train_loss: 6.7633 | val_loss: 6.2164
# Epoch 10/10 train_loss: 6.5792 | val_loss: 7.0118
# Model weights saved to models/lstm_model.pth
# Trial 8/48 with params: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.002, 'weight_decay': 0.0001, 'batch_size': 32, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 14.7507 | val_loss: 7.2791
# Epoch 2/10 train_loss: 9.3353 | val_loss: 7.4408
# Epoch 3/10 train_loss: 9.0178 | val_loss: 8.5352
# Epoch 4/10 train_loss: 8.8539 | val_loss: 7.2093
# Epoch 5/10 train_loss: 8.5760 | val_loss: 6.8451
# Epoch 6/10 train_loss: 8.3774 | val_loss: 7.0014
# Epoch 7/10 train_loss: 8.2144 | val_loss: 7.1183
# Epoch 8/10 train_loss: 7.8266 | val_loss: 7.4726
# Epoch 9/10 train_loss: 7.5307 | val_loss: 7.0802
# Epoch 10/10 train_loss: 7.1254 | val_loss: 7.0033
# Model weights saved to models/lstm_model.pth
# Trial 9/48 with params: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0, 'batch_size': 16, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 17.5101 | val_loss: 9.1062
# Epoch 2/10 train_loss: 9.7254 | val_loss: 7.8732
# Epoch 3/10 train_loss: 9.2161 | val_loss: 7.3867
# Epoch 4/10 train_loss: 8.9522 | val_loss: 7.0295
# Epoch 5/10 train_loss: 8.8158 | val_loss: 9.7350
# Epoch 6/10 train_loss: 8.5502 | val_loss: 7.5918
# Epoch 7/10 train_loss: 8.4084 | val_loss: 7.3822
# Epoch 8/10 train_loss: 8.2476 | val_loss: 7.6252
# Epoch 9/10 train_loss: 8.1713 | val_loss: 7.1986
# Epoch 10/10 train_loss: 8.0151 | val_loss: 7.5962
# Model weights saved to models/lstm_model.pth
# Trial 10/48 with params: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0, 'batch_size': 32, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 23.3465 | val_loss: 10.2202
# Epoch 2/10 train_loss: 11.0493 | val_loss: 7.6918
# Epoch 3/10 train_loss: 9.6902 | val_loss: 8.1116
# Epoch 4/10 train_loss: 9.3107 | val_loss: 8.2363
# Epoch 5/10 train_loss: 9.1039 | val_loss: 7.1396
# Epoch 6/10 train_loss: 8.8711 | val_loss: 7.3598
# Epoch 7/10 train_loss: 8.7685 | val_loss: 6.9926
# Epoch 8/10 train_loss: 8.5563 | val_loss: 7.0227
# Epoch 9/10 train_loss: 8.3915 | val_loss: 7.6467
# Epoch 10/10 train_loss: 8.3826 | val_loss: 8.3188
# Model weights saved to models/lstm_model.pth
# Trial 11/48 with params: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 16, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 17.6643 | val_loss: 9.2731
# Epoch 2/10 train_loss: 9.6960 | val_loss: 7.9717
# Epoch 3/10 train_loss: 9.2313 | val_loss: 6.8523
# Epoch 4/10 train_loss: 8.9155 | val_loss: 7.5598
# Epoch 5/10 train_loss: 8.6399 | val_loss: 7.1910
# Epoch 6/10 train_loss: 8.4807 | val_loss: 7.3072
# Epoch 7/10 train_loss: 8.1282 | val_loss: 7.3345
# Epoch 8/10 train_loss: 7.8587 | val_loss: 6.9042
# Epoch 9/10 train_loss: 7.6410 | val_loss: 6.8334
# Epoch 10/10 train_loss: 7.3304 | val_loss: 7.1102
# Model weights saved to models/lstm_model.pth
# Trial 12/48 with params: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 32, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 22.1822 | val_loss: 9.7419
# Epoch 2/10 train_loss: 10.4512 | val_loss: 7.9250
# Epoch 3/10 train_loss: 9.5080 | val_loss: 7.7837
# Epoch 4/10 train_loss: 9.1828 | val_loss: 7.9522
# Epoch 5/10 train_loss: 8.9659 | val_loss: 9.1378
# Epoch 6/10 train_loss: 8.7895 | val_loss: 6.9710
# Epoch 7/10 train_loss: 8.6679 | val_loss: 7.6901
# Epoch 8/10 train_loss: 8.5332 | val_loss: 7.2780
# Epoch 9/10 train_loss: 8.3953 | val_loss: 7.1284
# Epoch 10/10 train_loss: 8.3722 | val_loss: 7.4001
# Model weights saved to models/lstm_model.pth
# Trial 13/48 with params: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.3, 'lr': 0.001, 'weight_decay': 0.0, 'batch_size': 16, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 14.6047 | val_loss: 6.8827
# Epoch 2/10 train_loss: 9.4104 | val_loss: 9.6652
# Epoch 3/10 train_loss: 9.1248 | val_loss: 7.9937
# Epoch 4/10 train_loss: 8.7657 | val_loss: 8.9100
# Epoch 5/10 train_loss: 8.7356 | val_loss: 6.5896
# Epoch 6/10 train_loss: 8.5149 | val_loss: 6.7616
# Epoch 7/10 train_loss: 8.3126 | val_loss: 7.7938
# Epoch 8/10 train_loss: 8.1187 | val_loss: 7.4890
# Epoch 9/10 train_loss: 7.9291 | val_loss: 7.5331
# Epoch 10/10 train_loss: 7.5744 | val_loss: 8.0554
# Model weights saved to models/lstm_model.pth
# Trial 14/48 with params: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.3, 'lr': 0.001, 'weight_decay': 0.0, 'batch_size': 32, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 16.8351 | val_loss: 7.0658
# Epoch 2/10 train_loss: 9.4409 | val_loss: 8.0314
# Epoch 3/10 train_loss: 9.1978 | val_loss: 7.5369
# Epoch 4/10 train_loss: 8.8554 | val_loss: 6.5913
# Epoch 5/10 train_loss: 8.6280 | val_loss: 7.0795
# Epoch 6/10 train_loss: 8.3288 | val_loss: 7.1940
# Epoch 7/10 train_loss: 7.9680 | val_loss: 6.8178
# Epoch 8/10 train_loss: 7.7840 | val_loss: 6.8612
# Epoch 9/10 train_loss: 7.6600 | val_loss: 6.8109
# Epoch 10/10 train_loss: 7.3417 | val_loss: 6.9511
# Model weights saved to models/lstm_model.pth
# Trial 15/48 with params: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.3, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 16, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 14.4409 | val_loss: 7.6024
# Epoch 2/10 train_loss: 9.3977 | val_loss: 7.8808
# Epoch 3/10 train_loss: 8.9900 | val_loss: 7.7401
# Epoch 4/10 train_loss: 8.8157 | val_loss: 7.7024
# Epoch 5/10 train_loss: 8.5736 | val_loss: 6.8893
# Epoch 6/10 train_loss: 8.3179 | val_loss: 7.1760
# Epoch 7/10 train_loss: 8.2614 | val_loss: 7.1802
# Epoch 8/10 train_loss: 8.0755 | val_loss: 7.7054
# Epoch 9/10 train_loss: 7.8810 | val_loss: 7.5614
# Epoch 10/10 train_loss: 7.6205 | val_loss: 7.6523
# Model weights saved to models/lstm_model.pth
# Trial 16/48 with params: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.3, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 32, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 17.2023 | val_loss: 8.0008
# Epoch 2/10 train_loss: 9.6666 | val_loss: 7.2125
# Epoch 3/10 train_loss: 9.1007 | val_loss: 7.2186
# Epoch 4/10 train_loss: 8.8356 | val_loss: 7.2696
# Epoch 5/10 train_loss: 8.6055 | val_loss: 7.4886
# Epoch 6/10 train_loss: 8.5630 | val_loss: 7.0434
# Epoch 7/10 train_loss: 8.3689 | val_loss: 7.6926
# Epoch 8/10 train_loss: 8.1475 | val_loss: 7.0943
# Epoch 9/10 train_loss: 7.8341 | val_loss: 7.4697
# Epoch 10/10 train_loss: 7.5672 | val_loss: 7.5222
# Model weights saved to models/lstm_model.pth
# Trial 17/48 with params: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.3, 'lr': 0.002, 'weight_decay': 0.0, 'batch_size': 16, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 13.0286 | val_loss: 9.9273
# Epoch 2/10 train_loss: 9.2756 | val_loss: 7.2113
# Epoch 3/10 train_loss: 8.6529 | val_loss: 8.3686
# Epoch 4/10 train_loss: 8.4182 | val_loss: 6.7429
# Epoch 5/10 train_loss: 7.7706 | val_loss: 6.9206
# Epoch 6/10 train_loss: 7.4966 | val_loss: 6.6834
# Epoch 7/10 train_loss: 7.1153 | val_loss: 6.5777
# Epoch 8/10 train_loss: 6.8344 | val_loss: 6.6725
# Epoch 9/10 train_loss: 6.4113 | val_loss: 6.7858
# Epoch 10/10 train_loss: 6.0723 | val_loss: 6.8964
# Model weights saved to models/lstm_model.pth
# Trial 18/48 with params: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.3, 'lr': 0.002, 'weight_decay': 0.0, 'batch_size': 32, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 15.0722 | val_loss: 8.5448
# Epoch 2/10 train_loss: 9.4332 | val_loss: 6.9948
# Epoch 3/10 train_loss: 9.0810 | val_loss: 7.3410
# Epoch 4/10 train_loss: 8.7441 | val_loss: 8.4798
# Epoch 5/10 train_loss: 8.5076 | val_loss: 7.3671
# Epoch 6/10 train_loss: 8.4203 | val_loss: 7.7387
# Epoch 7/10 train_loss: 8.2414 | val_loss: 7.1169
# Epoch 8/10 train_loss: 7.9421 | val_loss: 8.2460
# Epoch 9/10 train_loss: 7.6157 | val_loss: 7.5839
# Epoch 10/10 train_loss: 7.1776 | val_loss: 6.5076
# Model weights saved to models/lstm_model.pth
# Trial 19/48 with params: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.3, 'lr': 0.002, 'weight_decay': 0.0001, 'batch_size': 16, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 13.0672 | val_loss: 7.4383
# Epoch 2/10 train_loss: 9.3170 | val_loss: 7.3295
# Epoch 3/10 train_loss: 9.0090 | val_loss: 6.4986
# Epoch 4/10 train_loss: 8.7590 | val_loss: 6.4926
# Epoch 5/10 train_loss: 8.4543 | val_loss: 8.2731
# Epoch 6/10 train_loss: 7.9966 | val_loss: 6.6111
# Epoch 7/10 train_loss: 7.7260 | val_loss: 6.0888
# Epoch 8/10 train_loss: 7.3309 | val_loss: 6.3500
# Epoch 9/10 train_loss: 7.1398 | val_loss: 5.9018
# Epoch 10/10 train_loss: 6.8829 | val_loss: 6.4830
# Model weights saved to models/lstm_model.pth
# Trial 20/48 with params: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.3, 'lr': 0.002, 'weight_decay': 0.0001, 'batch_size': 32, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 14.9406 | val_loss: 7.3947
# Epoch 2/10 train_loss: 9.4202 | val_loss: 8.7521
# Epoch 3/10 train_loss: 9.1174 | val_loss: 7.1979
# Epoch 4/10 train_loss: 8.8934 | val_loss: 7.0310
# Epoch 5/10 train_loss: 8.7393 | val_loss: 7.4056
# Epoch 6/10 train_loss: 8.5368 | val_loss: 7.6702
# Epoch 7/10 train_loss: 8.2838 | val_loss: 6.8154
# Epoch 8/10 train_loss: 8.0821 | val_loss: 7.2208
# Epoch 9/10 train_loss: 7.8745 | val_loss: 7.3251
# Epoch 10/10 train_loss: 7.4936 | val_loss: 6.6002
# Model weights saved to models/lstm_model.pth
# Trial 21/48 with params: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.3, 'lr': 0.0005, 'weight_decay': 0.0, 'batch_size': 16, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 16.9094 | val_loss: 10.4785
# Epoch 2/10 train_loss: 9.6973 | val_loss: 7.8967
# Epoch 3/10 train_loss: 9.1310 | val_loss: 7.7626
# Epoch 4/10 train_loss: 8.8950 | val_loss: 7.7067
# Epoch 5/10 train_loss: 8.5958 | val_loss: 7.1749
# Epoch 6/10 train_loss: 8.5063 | val_loss: 7.3837
# Epoch 7/10 train_loss: 8.2612 | val_loss: 6.6145
# Epoch 8/10 train_loss: 8.2205 | val_loss: 7.1150
# Epoch 9/10 train_loss: 8.0469 | val_loss: 7.1086
# Epoch 10/10 train_loss: 7.7714 | val_loss: 6.5187
# Model weights saved to models/lstm_model.pth
# Trial 22/48 with params: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.3, 'lr': 0.0005, 'weight_decay': 0.0, 'batch_size': 32, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 21.6853 | val_loss: 8.8281
# Epoch 2/10 train_loss: 10.4770 | val_loss: 8.1562
# Epoch 3/10 train_loss: 9.5483 | val_loss: 7.3785
# Epoch 4/10 train_loss: 9.2245 | val_loss: 9.0566
# Epoch 5/10 train_loss: 8.9255 | val_loss: 6.9437
# Epoch 6/10 train_loss: 8.8931 | val_loss: 7.6643
# Epoch 7/10 train_loss: 8.6072 | val_loss: 8.4213
# Epoch 8/10 train_loss: 8.5114 | val_loss: 7.2678
# Epoch 9/10 train_loss: 8.3387 | val_loss: 7.7555
# Epoch 10/10 train_loss: 8.1903 | val_loss: 7.3733
# Model weights saved to models/lstm_model.pth
# Trial 23/48 with params: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.3, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 16, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 17.1978 | val_loss: 7.4108
# Epoch 2/10 train_loss: 9.8751 | val_loss: 8.6517
# Epoch 3/10 train_loss: 9.1118 | val_loss: 7.8530
# Epoch 4/10 train_loss: 8.8200 | val_loss: 7.3857
# Epoch 5/10 train_loss: 8.6488 | val_loss: 7.3167
# Epoch 6/10 train_loss: 8.6063 | val_loss: 9.0269
# Epoch 7/10 train_loss: 8.4135 | val_loss: 7.8401
# Epoch 8/10 train_loss: 8.1643 | val_loss: 7.1235
# Epoch 9/10 train_loss: 8.0585 | val_loss: 7.1924
# Epoch 10/10 train_loss: 7.9014 | val_loss: 7.5449
# Model weights saved to models/lstm_model.pth
# Trial 24/48 with params: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.3, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 32, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 22.2931 | val_loss: 8.5560
# Epoch 2/10 train_loss: 10.5226 | val_loss: 7.1158
# Epoch 3/10 train_loss: 9.6696 | val_loss: 8.7223
# Epoch 4/10 train_loss: 9.2093 | val_loss: 7.2079
# Epoch 5/10 train_loss: 9.0106 | val_loss: 7.0418
# Epoch 6/10 train_loss: 8.7397 | val_loss: 7.2653
# Epoch 7/10 train_loss: 8.7294 | val_loss: 6.6090
# Epoch 8/10 train_loss: 8.6591 | val_loss: 7.5158
# Epoch 9/10 train_loss: 8.4535 | val_loss: 7.2320
# Epoch 10/10 train_loss: 8.4518 | val_loss: 7.4261
# Model weights saved to models/lstm_model.pth
# Trial 25/48 with params: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0, 'batch_size': 16, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 14.7232 | val_loss: 8.2185
# Epoch 2/10 train_loss: 9.6577 | val_loss: 8.5561
# Epoch 3/10 train_loss: 9.1720 | val_loss: 7.2308
# Epoch 4/10 train_loss: 8.8282 | val_loss: 7.2520
# Epoch 5/10 train_loss: 8.4951 | val_loss: 7.8228
# Epoch 6/10 train_loss: 8.3400 | val_loss: 6.8423
# Epoch 7/10 train_loss: 8.0181 | val_loss: 9.3641
# Epoch 8/10 train_loss: 7.5000 | val_loss: 6.4205
# Epoch 9/10 train_loss: 7.2739 | val_loss: 6.1906
# Epoch 10/10 train_loss: 7.1433 | val_loss: 6.3079
# Model weights saved to models/lstm_model.pth
# Trial 26/48 with params: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0, 'batch_size': 32, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 20.3136 | val_loss: 7.9179
# Epoch 2/10 train_loss: 9.8025 | val_loss: 7.9476
# Epoch 3/10 train_loss: 9.2134 | val_loss: 6.9943
# Epoch 4/10 train_loss: 8.8988 | val_loss: 7.4855
# Epoch 5/10 train_loss: 8.7438 | val_loss: 7.3326
# Epoch 6/10 train_loss: 8.5226 | val_loss: 6.8973
# Epoch 7/10 train_loss: 8.1488 | val_loss: 7.3722
# Epoch 8/10 train_loss: 8.0094 | val_loss: 7.2125
# Epoch 9/10 train_loss: 7.7556 | val_loss: 6.5543
# Epoch 10/10 train_loss: 7.3157 | val_loss: 7.8902
# Model weights saved to models/lstm_model.pth
# Trial 27/48 with params: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 16, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 14.8440 | val_loss: 9.7817
# Epoch 2/10 train_loss: 9.4078 | val_loss: 8.3013
# Epoch 3/10 train_loss: 8.9706 | val_loss: 7.2329
# Epoch 4/10 train_loss: 8.6999 | val_loss: 6.8640
# Epoch 5/10 train_loss: 8.4395 | val_loss: 7.6735
# Epoch 6/10 train_loss: 8.1720 | val_loss: 7.3035
# Epoch 7/10 train_loss: 7.5825 | val_loss: 7.0652
# Epoch 8/10 train_loss: 7.1878 | val_loss: 6.9630
# Epoch 9/10 train_loss: 6.7931 | val_loss: 7.1887
# Epoch 10/10 train_loss: 6.5548 | val_loss: 6.2705
# Model weights saved to models/lstm_model.pth
# Trial 28/48 with params: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 32, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 19.1502 | val_loss: 10.2895
# Epoch 2/10 train_loss: 9.7123 | val_loss: 6.9928
# Epoch 3/10 train_loss: 9.1394 | val_loss: 7.2539
# Epoch 4/10 train_loss: 8.7852 | val_loss: 7.5955
# Epoch 5/10 train_loss: 8.5096 | val_loss: 7.3982
# Epoch 6/10 train_loss: 8.2320 | val_loss: 7.8228
# Epoch 7/10 train_loss: 7.8801 | val_loss: 7.0181
# Epoch 8/10 train_loss: 7.5590 | val_loss: 6.8237
# Epoch 9/10 train_loss: 7.2987 | val_loss: 7.5500
# Epoch 10/10 train_loss: 6.9670 | val_loss: 6.7202
# Model weights saved to models/lstm_model.pth
# Trial 29/48 with params: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.0, 'lr': 0.002, 'weight_decay': 0.0, 'batch_size': 16, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 14.2267 | val_loss: 6.7335
# Epoch 2/10 train_loss: 9.4932 | val_loss: 8.0041
# Epoch 3/10 train_loss: 9.0484 | val_loss: 7.4107
# Epoch 4/10 train_loss: 8.8407 | val_loss: 6.7532
# Epoch 5/10 train_loss: 8.5422 | val_loss: 7.2596
# Epoch 6/10 train_loss: 8.1815 | val_loss: 6.4339
# Epoch 7/10 train_loss: 7.7823 | val_loss: 6.6162
# Epoch 8/10 train_loss: 7.3731 | val_loss: 6.1733
# Epoch 9/10 train_loss: 7.1753 | val_loss: 7.6833
# Epoch 10/10 train_loss: 6.8495 | val_loss: 6.5097
# Model weights saved to models/lstm_model.pth
# Trial 30/48 with params: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.0, 'lr': 0.002, 'weight_decay': 0.0, 'batch_size': 32, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 16.9408 | val_loss: 8.3226
# Epoch 2/10 train_loss: 9.4839 | val_loss: 7.8615
# Epoch 3/10 train_loss: 9.0190 | val_loss: 7.6504
# Epoch 4/10 train_loss: 8.6660 | val_loss: 6.9417
# Epoch 5/10 train_loss: 8.3786 | val_loss: 7.3682
# Epoch 6/10 train_loss: 8.0920 | val_loss: 6.6087
# Epoch 7/10 train_loss: 7.5609 | val_loss: 7.2326
# Epoch 8/10 train_loss: 7.2144 | val_loss: 6.8137
# Epoch 9/10 train_loss: 6.9055 | val_loss: 6.5795
# Epoch 10/10 train_loss: 6.6729 | val_loss: 6.6645
# Model weights saved to models/lstm_model.pth
# Trial 31/48 with params: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.0, 'lr': 0.002, 'weight_decay': 0.0001, 'batch_size': 16, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 13.9682 | val_loss: 7.1829
# Epoch 2/10 train_loss: 9.5489 | val_loss: 6.6353
# Epoch 3/10 train_loss: 9.1001 | val_loss: 6.8264
# Epoch 4/10 train_loss: 8.6974 | val_loss: 8.0792
# Epoch 5/10 train_loss: 8.5201 | val_loss: 7.2381
# Epoch 6/10 train_loss: 8.2961 | val_loss: 6.7590
# Epoch 7/10 train_loss: 7.9871 | val_loss: 6.4579
# Epoch 8/10 train_loss: 7.5685 | val_loss: 7.1911
# Epoch 9/10 train_loss: 7.2041 | val_loss: 6.5851
# Epoch 10/10 train_loss: 6.9992 | val_loss: 7.1418
# Model weights saved to models/lstm_model.pth
# Trial 32/48 with params: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.0, 'lr': 0.002, 'weight_decay': 0.0001, 'batch_size': 32, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 15.9259 | val_loss: 7.6757
# Epoch 2/10 train_loss: 9.3611 | val_loss: 8.5421
# Epoch 3/10 train_loss: 8.8549 | val_loss: 7.1103
# Epoch 4/10 train_loss: 8.5034 | val_loss: 7.4616
# Epoch 5/10 train_loss: 8.2414 | val_loss: 7.3772
# Epoch 6/10 train_loss: 7.8006 | val_loss: 6.6012
# Epoch 7/10 train_loss: 7.4062 | val_loss: 6.2179
# Epoch 8/10 train_loss: 6.9198 | val_loss: 5.8699
# Epoch 9/10 train_loss: 6.5651 | val_loss: 7.2358
# Epoch 10/10 train_loss: 6.3306 | val_loss: 6.8929
# Model weights saved to models/lstm_model.pth
# Trial 33/48 with params: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0, 'batch_size': 16, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 16.5839 | val_loss: 7.8766
# Epoch 2/10 train_loss: 9.6991 | val_loss: 8.2059
# Epoch 3/10 train_loss: 9.1637 | val_loss: 7.1550
# Epoch 4/10 train_loss: 8.9211 | val_loss: 8.2590
# Epoch 5/10 train_loss: 8.6442 | val_loss: 7.4754
# Epoch 6/10 train_loss: 8.4205 | val_loss: 6.7964
# Epoch 7/10 train_loss: 8.2319 | val_loss: 7.3885
# Epoch 8/10 train_loss: 7.8672 | val_loss: 6.9767
# Epoch 9/10 train_loss: 7.6093 | val_loss: 7.2921
# Epoch 10/10 train_loss: 7.1277 | val_loss: 7.6569
# Model weights saved to models/lstm_model.pth
# Trial 34/48 with params: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0, 'batch_size': 32, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 24.8747 | val_loss: 8.9249
# Epoch 2/10 train_loss: 10.3100 | val_loss: 7.9162
# Epoch 3/10 train_loss: 9.4334 | val_loss: 8.5036
# Epoch 4/10 train_loss: 9.2169 | val_loss: 7.9281
# Epoch 5/10 train_loss: 8.8714 | val_loss: 7.3529
# Epoch 6/10 train_loss: 8.6295 | val_loss: 7.2222
# Epoch 7/10 train_loss: 8.4518 | val_loss: 8.0629
# Epoch 8/10 train_loss: 8.2119 | val_loss: 6.9931
# Epoch 9/10 train_loss: 8.0119 | val_loss: 7.6370
# Epoch 10/10 train_loss: 7.7180 | val_loss: 7.2256
# Model weights saved to models/lstm_model.pth
# Trial 35/48 with params: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 16, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 17.2220 | val_loss: 9.2173
# Epoch 2/10 train_loss: 9.8466 | val_loss: 7.5272
# Epoch 3/10 train_loss: 9.0589 | val_loss: 8.0554
# Epoch 4/10 train_loss: 8.8002 | val_loss: 8.7297
# Epoch 5/10 train_loss: 8.3583 | val_loss: 7.4025
# Epoch 6/10 train_loss: 7.9659 | val_loss: 7.7299
# Epoch 7/10 train_loss: 7.4686 | val_loss: 7.0030
# Epoch 8/10 train_loss: 6.9897 | val_loss: 7.0999
# Epoch 9/10 train_loss: 6.4233 | val_loss: 6.3102
# Epoch 10/10 train_loss: 6.0860 | val_loss: 7.7490
# Model weights saved to models/lstm_model.pth
# Trial 36/48 with params: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 32, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 22.2447 | val_loss: 8.0462
# Epoch 2/10 train_loss: 10.1384 | val_loss: 6.9173
# Epoch 3/10 train_loss: 9.4928 | val_loss: 6.8886
# Epoch 4/10 train_loss: 9.2297 | val_loss: 7.1614
# Epoch 5/10 train_loss: 8.8564 | val_loss: 6.6711
# Epoch 6/10 train_loss: 8.6136 | val_loss: 7.7540
# Epoch 7/10 train_loss: 8.4800 | val_loss: 6.8399
# Epoch 8/10 train_loss: 8.2991 | val_loss: 7.2174
# Epoch 9/10 train_loss: 8.1532 | val_loss: 6.7193
# Epoch 10/10 train_loss: 7.7468 | val_loss: 7.0892
# Model weights saved to models/lstm_model.pth
# Trial 37/48 with params: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.3, 'lr': 0.001, 'weight_decay': 0.0, 'batch_size': 16, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 16.9398 | val_loss: 6.9028
# Epoch 2/10 train_loss: 9.7845 | val_loss: 7.0160
# Epoch 3/10 train_loss: 9.3871 | val_loss: 6.9884
# Epoch 4/10 train_loss: 8.8977 | val_loss: 7.1362
# Epoch 5/10 train_loss: 8.7322 | val_loss: 7.6054
# Epoch 6/10 train_loss: 8.3938 | val_loss: 6.9085
# Epoch 7/10 train_loss: 8.0113 | val_loss: 6.6981
# Epoch 8/10 train_loss: 7.5842 | val_loss: 8.1734
# Epoch 9/10 train_loss: 7.1561 | val_loss: 8.0088
# Epoch 10/10 train_loss: 6.7903 | val_loss: 7.5355
# Model weights saved to models/lstm_model.pth
# Trial 38/48 with params: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.3, 'lr': 0.001, 'weight_decay': 0.0, 'batch_size': 32, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 18.7851 | val_loss: 8.4796
# Epoch 2/10 train_loss: 9.8640 | val_loss: 6.6375
# Epoch 3/10 train_loss: 9.1986 | val_loss: 7.3699
# Epoch 4/10 train_loss: 9.1136 | val_loss: 6.8903
# Epoch 5/10 train_loss: 8.9036 | val_loss: 6.7713
# Epoch 6/10 train_loss: 8.5406 | val_loss: 6.9025
# Epoch 7/10 train_loss: 8.4378 | val_loss: 7.2783
# Epoch 8/10 train_loss: 8.1405 | val_loss: 7.1752
# Epoch 9/10 train_loss: 7.7818 | val_loss: 6.8657
# Epoch 10/10 train_loss: 7.3329 | val_loss: 7.2837
# Model weights saved to models/lstm_model.pth
# Trial 39/48 with params: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.3, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 16, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 15.0594 | val_loss: 7.2525
# Epoch 2/10 train_loss: 9.6835 | val_loss: 7.0489
# Epoch 3/10 train_loss: 9.2036 | val_loss: 6.9529
# Epoch 4/10 train_loss: 8.8537 | val_loss: 7.2668
# Epoch 5/10 train_loss: 8.5619 | val_loss: 8.2485
# Epoch 6/10 train_loss: 8.3354 | val_loss: 7.0258
# Epoch 7/10 train_loss: 8.0506 | val_loss: 8.0474
# Epoch 8/10 train_loss: 7.7574 | val_loss: 7.0800
# Epoch 9/10 train_loss: 7.3211 | val_loss: 7.6516
# Epoch 10/10 train_loss: 6.9535 | val_loss: 7.1146
# Model weights saved to models/lstm_model.pth
# Trial 40/48 with params: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.3, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 32, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 19.3051 | val_loss: 9.0472
# Epoch 2/10 train_loss: 9.8710 | val_loss: 7.3747
# Epoch 3/10 train_loss: 9.2474 | val_loss: 7.3021
# Epoch 4/10 train_loss: 9.1004 | val_loss: 8.0343
# Epoch 5/10 train_loss: 8.7724 | val_loss: 7.0543
# Epoch 6/10 train_loss: 8.5403 | val_loss: 7.9454
# Epoch 7/10 train_loss: 8.3995 | val_loss: 7.7997
# Epoch 8/10 train_loss: 8.1827 | val_loss: 7.2444
# Epoch 9/10 train_loss: 8.0090 | val_loss: 7.1488
# Epoch 10/10 train_loss: 7.7827 | val_loss: 7.2432
# Model weights saved to models/lstm_model.pth
# Trial 41/48 with params: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.3, 'lr': 0.002, 'weight_decay': 0.0, 'batch_size': 16, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 13.9014 | val_loss: 8.3410
# Epoch 2/10 train_loss: 9.6007 | val_loss: 8.1711
# Epoch 3/10 train_loss: 9.1167 | val_loss: 6.9313
# Epoch 4/10 train_loss: 8.8225 | val_loss: 7.7979
# Epoch 5/10 train_loss: 8.5399 | val_loss: 9.0868
# Epoch 6/10 train_loss: 8.1618 | val_loss: 6.8006
# Epoch 7/10 train_loss: 7.7712 | val_loss: 7.6215
# Epoch 8/10 train_loss: 7.1789 | val_loss: 7.7926
# Epoch 9/10 train_loss: 6.7559 | val_loss: 8.8527
# Epoch 10/10 train_loss: 6.2049 | val_loss: 9.6302
# Model weights saved to models/lstm_model.pth
# Trial 42/48 with params: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.3, 'lr': 0.002, 'weight_decay': 0.0, 'batch_size': 32, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 16.2878 | val_loss: 7.9405
# Epoch 2/10 train_loss: 10.0136 | val_loss: 7.9090
# Epoch 3/10 train_loss: 9.3832 | val_loss: 7.4220
# Epoch 4/10 train_loss: 9.1091 | val_loss: 8.0019
# Epoch 5/10 train_loss: 8.6165 | val_loss: 7.2320
# Epoch 6/10 train_loss: 8.4126 | val_loss: 7.2378
# Epoch 7/10 train_loss: 7.9058 | val_loss: 8.6866
# Epoch 8/10 train_loss: 7.5763 | val_loss: 7.3015
# Epoch 9/10 train_loss: 7.2456 | val_loss: 7.3499
# Epoch 10/10 train_loss: 7.1070 | val_loss: 7.1494
# Model weights saved to models/lstm_model.pth
# Trial 43/48 with params: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.3, 'lr': 0.002, 'weight_decay': 0.0001, 'batch_size': 16, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 14.3471 | val_loss: 7.2736
# Epoch 2/10 train_loss: 9.7299 | val_loss: 7.7246
# Epoch 3/10 train_loss: 9.2320 | val_loss: 7.9431
# Epoch 4/10 train_loss: 8.7820 | val_loss: 7.0948
# Epoch 5/10 train_loss: 8.5873 | val_loss: 6.8550
# Epoch 6/10 train_loss: 8.3132 | val_loss: 7.4117
# Epoch 7/10 train_loss: 7.9931 | val_loss: 7.2383
# Epoch 8/10 train_loss: 7.7620 | val_loss: 6.9283
# Epoch 9/10 train_loss: 7.4524 | val_loss: 8.3490
# Epoch 10/10 train_loss: 7.0665 | val_loss: 8.9951
# Model weights saved to models/lstm_model.pth
# Trial 44/48 with params: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.3, 'lr': 0.002, 'weight_decay': 0.0001, 'batch_size': 32, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 17.4989 | val_loss: 7.4632
# Epoch 2/10 train_loss: 9.6644 | val_loss: 7.5162
# Epoch 3/10 train_loss: 9.3211 | val_loss: 6.6696
# Epoch 4/10 train_loss: 8.9123 | val_loss: 7.3055
# Epoch 5/10 train_loss: 8.6995 | val_loss: 7.5738
# Epoch 6/10 train_loss: 8.4298 | val_loss: 6.9750
# Epoch 7/10 train_loss: 8.0614 | val_loss: 7.2467
# Epoch 8/10 train_loss: 7.7060 | val_loss: 7.0134
# Epoch 9/10 train_loss: 7.2955 | val_loss: 7.9809
# Epoch 10/10 train_loss: 6.9632 | val_loss: 7.6596
# Model weights saved to models/lstm_model.pth
# Trial 45/48 with params: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.3, 'lr': 0.0005, 'weight_decay': 0.0, 'batch_size': 16, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 20.1793 | val_loss: 7.5906
# Epoch 2/10 train_loss: 10.0818 | val_loss: 8.8100
# Epoch 3/10 train_loss: 9.4559 | val_loss: 8.1398
# Epoch 4/10 train_loss: 9.0665 | val_loss: 7.1385
# Epoch 5/10 train_loss: 8.8434 | val_loss: 7.8680
# Epoch 6/10 train_loss: 8.6382 | val_loss: 8.3037
# Epoch 7/10 train_loss: 8.3669 | val_loss: 7.7920
# Epoch 8/10 train_loss: 7.9661 | val_loss: 7.1497
# Epoch 9/10 train_loss: 7.7627 | val_loss: 7.3318
# Epoch 10/10 train_loss: 7.4701 | val_loss: 7.4466
# Model weights saved to models/lstm_model.pth
# Trial 46/48 with params: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.3, 'lr': 0.0005, 'weight_decay': 0.0, 'batch_size': 32, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 24.2024 | val_loss: 11.2489
# Epoch 2/10 train_loss: 10.6513 | val_loss: 8.7322
# Epoch 3/10 train_loss: 9.7131 | val_loss: 7.7603
# Epoch 4/10 train_loss: 9.2098 | val_loss: 9.1004
# Epoch 5/10 train_loss: 8.8493 | val_loss: 7.3329
# Epoch 6/10 train_loss: 8.5812 | val_loss: 7.6653
# Epoch 7/10 train_loss: 8.2855 | val_loss: 7.2733
# Epoch 8/10 train_loss: 7.9592 | val_loss: 7.0599
# Epoch 9/10 train_loss: 7.6353 | val_loss: 7.6532
# Epoch 10/10 train_loss: 7.2256 | val_loss: 7.4848
# Model weights saved to models/lstm_model.pth
# Trial 47/48 with params: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.3, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 16, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 18.2541 | val_loss: 8.2748
# Epoch 2/10 train_loss: 9.9833 | val_loss: 8.0125
# Epoch 3/10 train_loss: 9.4782 | val_loss: 8.0093
# Epoch 4/10 train_loss: 8.9352 | val_loss: 7.0493
# Epoch 5/10 train_loss: 8.7665 | val_loss: 7.2205
# Epoch 6/10 train_loss: 8.4273 | val_loss: 7.5384
# Epoch 7/10 train_loss: 8.2434 | val_loss: 7.8897
# Epoch 8/10 train_loss: 7.6727 | val_loss: 7.8099
# Epoch 9/10 train_loss: 7.3418 | val_loss: 7.5946
# Epoch 10/10 train_loss: 6.8534 | val_loss: 8.8385
# Model weights saved to models/lstm_model.pth
# Trial 48/48 with params: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.3, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 32, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200}
# Epoch 1/10 train_loss: 24.2921 | val_loss: 8.9226
# Epoch 2/10 train_loss: 10.5944 | val_loss: 10.6172
# Epoch 3/10 train_loss: 9.7624 | val_loss: 8.1070
# Epoch 4/10 train_loss: 9.3926 | val_loss: 8.0719
# Epoch 5/10 train_loss: 9.1696 | val_loss: 7.7065
# Epoch 6/10 train_loss: 8.9552 | val_loss: 7.6713
# Epoch 7/10 train_loss: 8.8631 | val_loss: 7.4172
# Epoch 8/10 train_loss: 8.7089 | val_loss: 7.2606
# Epoch 9/10 train_loss: 8.6049 | val_loss: 7.6868
# Epoch 10/10 train_loss: 8.4322 | val_loss: 7.0148
# Model weights saved to models/lstm_model.pth
# best: (5.86987749062632, {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.0, 'lr': 0.002, 'weight_decay': 0.0001, 'batch_size': 32, 'samples_per_epoch': 60000, 'l_min': 30, 'l_max': 200})

# %% [markdown]
# The training was carried out with 48 training runs on 15 epochs each covering all of the different combinations in parameters eg. varying learning rates, dropout rates, sizes of inner layers, dropout, weight decay, batch sizes.
#
# The optimal parameters showed to be:
#
# 'hidden_size': 64
# 'num_layers': 1
# 'dropout': 0.0
# 'lr': 0.001
# 'weight_decay': 0.0
# 'batch_size': 16,
# 'samples_per_epoch': 60000
# 'l_min': 30
# 'l_max': 200

# %% [markdown]
# ## Evaluation metrics
# Compute SmoothL1, MAE, and RMSE for validation/test.

# %%
@torch.no_grad()
def evaluate(model, loader, device):
    model.eval()

    smoothl1 = nn.SmoothL1Loss(reduction="mean")
    l1 = nn.L1Loss(reduction="mean")
    mse = nn.MSELoss(reduction="mean")

    total_smoothl1 = 0.0
    total_l1 = 0.0
    total_mse = 0.0
    total_samples = 0

    all_preds = []
    all_targets = []

    for padded, lengths, targets in loader:
        padded = padded.to(device)
        lengths = lengths.to(device)
        targets = targets.to(device)
        
        print("Evaluating batch with padded shape:", padded.shape)
        print("Lengths:", lengths)
        preds = model(padded, lengths)

        bs = targets.size(0)
        total_smoothl1 += smoothl1(preds, targets).item() * bs
        total_l1 += l1(preds, targets).item() * bs
        total_mse += mse(preds, targets).item() * bs
        total_samples += bs

        all_preds.append(preds.detach().cpu())
        all_targets.append(targets.detach().cpu())

    mean_smoothl1 = total_smoothl1 / max(total_samples, 1)
    mean_mae = total_l1 / max(total_samples, 1)
    mean_rmse = float(np.sqrt(total_mse / max(total_samples, 1)))

    preds_cat = torch.cat(all_preds).numpy()
    targets_cat = torch.cat(all_targets).numpy()

    return mean_smoothl1, mean_mae, mean_rmse, preds_cat, targets_cat

model = RulLstm(
    n_features=len(feature_cols),
    hidden_size=best[1]["hidden_size"],
    num_layers=best[1]["num_layers"],
    dropout=best[1]["dropout"],
).to(device)
model.load_state_dict(torch.load('models/lstm_model.pth'))


smoothl1_loss, mae, rmse, preds, targets = evaluate(model, test_loader, device)

print(f"Test SmoothL1: {smoothl1_loss:.4f}")
print(f"Test MAE:      {mae:.4f}")
print(f"Test RMSE:     {rmse:.4f}")


plt.figure(figsize=(10, 5))
plt.plot(targets, label="True RUL")
plt.plot(preds, label="Pred RUL")
plt.legend()
plt.show()
# Out:
# Evaluating batch with padded shape: torch.Size([32, 217, 16])
# Lengths: tensor([ 31,  49, 126, 106,  98, 105, 160, 166,  55, 192,  83, 217, 195,  46,
#          76, 113, 165, 133, 135, 184, 148,  39, 130, 186,  48,  76, 140, 158,
#         171, 143, 196, 145], device='cuda:0')
# Evaluating batch with padded shape: torch.Size([32, 303, 16])
# Lengths: tensor([ 50, 203, 198, 126, 121, 125,  37, 133, 123, 156, 172,  54, 152, 146,
#          73,  78, 303,  74, 144, 189, 164, 121, 113, 136, 160, 176,  94, 147,
#         159, 232, 155, 168], device='cuda:0')
# Evaluating batch with padded shape: torch.Size([32, 244, 16])
# Lengths: tensor([ 71, 147,  71, 187,  54, 152,  68, 131, 112, 137,  88, 205, 162,  72,
#         101, 133, 213, 162,  73, 172,  34, 110,  56,  68, 177, 146, 234, 150,
#         244, 133,  89,  97], device='cuda:0')
# Evaluating batch with padded shape: torch.Size([4, 198, 16])
# Lengths: tensor([134, 121,  97, 198], device='cuda:0')
# Test SmoothL1: 10.8867
# Test MAE:      11.3603
# Test RMSE:     16.6115

# %% [markdown]
# ## Error analysis (cycles)
# Report errors in raw cycles and visualize error distribution and per-unit error.

# %%
import numpy as np

errors = preds - targets
abs_errors = np.abs(errors)

mae_cycles = abs_errors.mean()
rmse_cycles = np.sqrt(np.mean(errors ** 2))

print(f"Test MAE (cycles): {mae_cycles:.2f}")
print(f"Test RMSE (cycles): {rmse_cycles:.2f}")

plt.figure(figsize=(8, 4))
plt.hist(errors, bins=30, edgecolor="black")
plt.axvline(0, color="black", linestyle="--", linewidth=1)
plt.title("Prediction error distribution (pred - true)")
plt.xlabel("Error (cycles)")
plt.ylabel("Count")
plt.show()

unit_ids = sorted(test_sequences_by_unit.keys())
if len(unit_ids) == len(errors):
    plt.figure(figsize=(10, 4))
    plt.axhline(0, color="black", linestyle="--", linewidth=1)
    plt.scatter(unit_ids, errors, s=20)
    plt.title("Per-unit prediction error (pred - true)")
    plt.xlabel("Unit ID")
    plt.ylabel("Error (cycles)")
    plt.show()
else:
    print("Warning: unit count does not match number of predictions")
# Out:
# Test MAE (cycles): 11.36
# Test RMSE (cycles): 16.61

# %%
@torch.no_grad()
def plot_many_units_last_prediction(
    model,
    scaled_test_df,
    rul_labels_df,
    feature_cols,
    device=None,
    unit_ids=None,
    cols=3,
):
    if device is None:
        device = next(model.parameters()).device
    else:
        device = torch.device(device)

    model = model.to(device)
    model.eval()

    if unit_ids is None:
        unit_ids = sorted(scaled_test_df["unit_nr"].unique())

    test_unit_ids_all = sorted(scaled_test_df["unit_nr"].unique().tolist())
    rul_by_unit = dict(zip(test_unit_ids_all, rul_labels_df["RUL_truth"].astype(float)))

    missing = set(feature_cols) - set(scaled_test_df.columns)
    if missing:
        raise ValueError(f"Missing feature cols in scaled_test_df: {sorted(missing)}")

    n = len(unit_ids)
    rows = int(math.ceil(n / cols))
    plt.figure(figsize=(5 * cols, 4 * rows))

    for i, unit_id in enumerate(unit_ids, start=1):
        g = scaled_test_df[scaled_test_df["unit_nr"] == unit_id].sort_values("time_cycles")
        if g.empty or unit_id not in rul_by_unit:
            continue

        full_seq = torch.tensor(g[feature_cols].to_numpy(), dtype=torch.float32, device=device)
        cycles = g["time_cycles"].to_numpy().astype(int)
        last_cycle = int(cycles[-1])

        true_rul_last = float(rul_by_unit[unit_id])
        failure_cycle = last_cycle + true_rul_last
        true_rul_curve = (failure_cycle - cycles).astype(float)

        padded = full_seq.unsqueeze(0)
        lengths = torch.tensor([full_seq.shape[0]], dtype=torch.long, device=device)

        try:
            pred_rul_last = float(model(padded, lengths)[0].item())
        except RuntimeError as e:
            print(f"Skipping unit {unit_id}: {e}")
            continue

        ax = plt.subplot(rows, cols, i)
        ax.plot(cycles, true_rul_curve, label="True")
        ax.scatter([last_cycle], [true_rul_last], label="True last")
        ax.scatter([last_cycle], [pred_rul_last], label="Pred last")
        ax.set_title(f"Unit {unit_id} | true={true_rul_last:.1f} pred={pred_rul_last:.1f}")
        ax.set_xlabel("Cycle")
        ax.set_ylabel("RUL")

        if i == 1:
            ax.legend()

    plt.tight_layout()
    plt.show()

# usage
plot_many_units_last_prediction(
    model=model,
    scaled_test_df=scaled_test_df,
    rul_labels_df=rul_labels_df,
    feature_cols=feature_cols,
    device=device,
    unit_ids=sorted(scaled_test_df["unit_nr"].unique())[:9],
    cols=3,
)

# %% [markdown]
# ## Export to ONNX
# Export the trained model for inference deployment.
#
# Why ONNX?
# - Portability: run the model without PyTorch via onnxruntime.
# - Deployment-friendly: smaller runtime footprint for Docker.
# - Performance: graph optimizations and accelerator support.
# - Consistency: frozen graph reduces training-time variability.

# %%
class OnnxRulLstm(nn.Module):
    def __init__(self, base):
        super().__init__()
        self.lstm = base.lstm
        self.head = base.head

    def forward(self, padded, lengths):
        out, _ = self.lstm(padded)  # [B, T, H]
        lengths = torch.clamp(lengths - 1, min=0)
        idx = lengths.view(-1, 1, 1).expand(-1, 1, out.size(2))
        last = out.gather(1, idx).squeeze(1)
        return self.head(last).squeeze(1)

model.to("cpu")
model.eval()

onnx_model = OnnxRulLstm(model).eval()

x = torch.randn(1, 217, 16)
lengths = torch.full((1,), 217, dtype=torch.long)

torch.onnx.export(
    onnx_model,
    (x, lengths),
    "models/lstm_model.onnx",
    input_names=["input", "lengths"],
    output_names=["output"],
    opset_version=18,
    dynamic_axes={
        "input": {0: "batch_size", 1: "sequence_length"},
        "lengths": {0: "batch_size"},
    },
    dynamo=False,
)
# Out:
# /tmp/ipykernel_3483259/3851463480.py:22: DeprecationWarning: You are using the legacy TorchScript-based ONNX export. Starting in PyTorch 2.9, the new torch.export-based ONNX exporter will be the default. To switch now, set dynamo=True in torch.onnx.export. This new exporter supports features like exporting LLMs with DynamicCache. We encourage you to try it and share feedback to help improve the experience. Learn more about the new export logic: https://pytorch.org/docs/stable/onnx_dynamo.html. For exporting control flow: https://pytorch.org/tutorials/beginner/onnx/export_control_flow_model_to_onnx_tutorial.html.
#   torch.onnx.export(
# /home/limin/Documents/programming/gemini-lstm-next-frame-prediction/.venv/lib/python3.12/site-packages/torch/onnx/_internal/torchscript_exporter/symbolic_opset9.py:4247: UserWarning: Exporting a model to ONNX with a batch_size other than 1, with a variable length with LSTM can cause an error when running the ONNX model with a different batch size. Make sure to save the model with a batch size of 1, or define the initial states (h0/c0) as inputs of the model.
#   warnings.warn(

# %%
import numpy as np
import onnxruntime as ort

sess = ort.InferenceSession("models/lstm_model.onnx", providers=["CPUExecutionProvider"])

seq, target, length = test_ds[20]

print("Evaluating test sequence with shape:", seq.shape)
print("Length:", length)
print("Target RUL:", target)

seq = seq.numpy().reshape(1, -1, seq.shape[1])

lengths = np.array([length], dtype=np.int64)
outputs = sess.run(None, {"input": seq, "lengths": lengths})

print("Number of outputs:", len(outputs))
for i, out in enumerate(outputs):
    print(f"Output[{i}] shape:", out.shape, "dtype:", out.dtype)
    print(f"Output[{i}] data:", out.item())  # Print the actual output data
# Out:
# Evaluating test sequence with shape: torch.Size([148, 16])
# Length: 148
# Target RUL: 57.0
# Number of outputs: 1
# Output[0] shape: (1,) dtype: float32
# Output[0] data: 67.66096496582031

# %% [markdown]
# The ONNX model is exported and ready for inference.
